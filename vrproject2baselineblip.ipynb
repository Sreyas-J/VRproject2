# %%
# !pip install -q --no-deps bert-score
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 2.9 MB/s eta 0:00:00

# %% [markdown]
# **Imports and Configurations**

# %%
import os
import pandas as pd
from PIL import Image
from tqdm.auto import tqdm

import torch
from transformers import BlipProcessor, BlipForQuestionAnswering
from accelerate import init_empty_weights, infer_auto_device_map

from nltk.translate.bleu_score import corpus_bleu, SmoothingFunction

from sklearn.metrics import accuracy_score,f1_score

from bert_score import score as bert_score
import numpy as np

import re
import nltk
from nltk.corpus import wordnet as wn
from torch.utils.data import IterableDataset

# Download required NLTK resources
nltk.download('wordnet')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('averaged_perceptron_tagger_eng')

MODEL_NAME="Salesforce/blip-vqa-base"
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
print(DEVICE)
# Out:
# [nltk_data] Downloading package wordnet to /usr/share/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /usr/share/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /usr/share/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /usr/share/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# cuda

# %% [markdown]
# **Load Dataset**

# %%
SUBSET_SIZE = 5000
DATA_CSV = "/kaggle/input/vrproject2dataset/vqa_dataset.csv"  # expected columns: ["path", "question", "answer"]
BATCH_SIZE = 8

df = pd.read_csv(DATA_CSV)

test_df = df.sample(n=SUBSET_SIZE, random_state=42).reset_index(drop=True)

# %% [markdown]
# **Initialize Processor and Model**

# %%
processor = BlipProcessor.from_pretrained("Salesforce/blip-vqa-base")
model = BlipForQuestionAnswering.from_pretrained(MODEL_NAME).to("cuda")

model.eval()
# Out:
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# preprocessor_config.json:   0%|          | 0.00/445 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/592 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/4.56k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.54G [00:00<?, ?B/s]
# BlipForQuestionAnswering(
#   (vision_model): BlipVisionModel(
#     (embeddings): BlipVisionEmbeddings(
#       (patch_embedding): Conv2d(3, 768, kernel_size=(16, 16), stride=(16, 16))
#     )
#     (encoder): BlipEncoder(
#       (layers): ModuleList(
#         (0-11): 12 x BlipEncoderLayer(
#           (self_attn): BlipAttention(
#             (dropout): Dropout(p=0.0, inplace=False)
#             (qkv): Linear(in_features=768, out_features=2304, bias=True)
#             (projection): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (layer_norm1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): BlipMLP(
#             (activation_fn): GELUActivation()
#             (fc1): Linear(in_features=768, out_features=3072, bias=True)
#             (fc2): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (layer_norm2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#     )
#     (post_layernorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   )
#   (text_encoder): BlipTextModel(
#     (embeddings): BlipTextEmbeddings(
#       (word_embeddings): Embedding(30524, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.0, inplace=False)
#     )
#     (encoder): BlipTextEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BlipTextLayer(
#           (attention): BlipTextAttention(
#             (self): BlipTextSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#             (output): BlipTextSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (crossattention): BlipTextAttention(
#             (self): BlipTextSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#             (output): BlipTextSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (intermediate): BlipTextIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BlipTextOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#         )
#       )
#     )
#   )
#   (text_decoder): BlipTextLMHeadModel(
#     (bert): BlipTextModel(
#       (embeddings): BlipTextEmbeddings(
#         (word_embeddings): Embedding(30524, 768, padding_idx=0)
#         (position_embeddings): Embedding(512, 768)
#         (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#       )
#       (encoder): BlipTextEncoder(
#         (layer): ModuleList(
#           (0-11): 12 x BlipTextLayer(
#             (attention): BlipTextAttention(
#               (self): BlipTextSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#               (output): BlipTextSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (crossattention): BlipTextAttention(
#               (self): BlipTextSelfAttention(
#                 (query): Linear(in_features=768, out_features=768, bias=True)
#                 (key): Linear(in_features=768, out_features=768, bias=True)
#                 (value): Linear(in_features=768, out_features=768, bias=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#               (output): BlipTextSelfOutput(
#                 (dense): Linear(in_features=768, out_features=768, bias=True)
#                 (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#                 (dropout): Dropout(p=0.0, inplace=False)
#               )
#             )
#             (intermediate): BlipTextIntermediate(
#               (dense): Linear(in_features=768, out_features=3072, bias=True)
#               (intermediate_act_fn): GELUActivation()
#             )
#             (output): BlipTextOutput(
#               (dense): Linear(in_features=3072, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#         )
#       )
#     )
#     (cls): BlipTextOnlyMLMHead(
#       (predictions): BlipTextLMPredictionHead(
#         (transform): BlipTextPredictionHeadTransform(
#           (dense): Linear(in_features=768, out_features=768, bias=True)
#           (transform_act_fn): GELUActivation()
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#         (decoder): Linear(in_features=768, out_features=30524, bias=True)
#       )
#     )
#   )
# )

# %% [markdown]
# **Helper: Number Word to Digit Map**

# %%
number_map = {
    'zero': '0', 'one': '1', 'two': '2', 'three': '3', 'four': '4',
    'five': '5', 'six': '6', 'seven': '7', 'eight': '8', 'nine': '9', 'ten': '10'
}

# %% [markdown]
# **WUPS Calculation Function**

# %%
# Map NLTK POS tags to WordNet POS categories for WUP similarity
def get_wordnet_pos(word):
    # Get POS tag for the word using NLTK
    tag = nltk.pos_tag([word])[0][1][0].upper()
    # Define mapping from NLTK tags to WordNet POS categories
    tag_dict = {"J": wn.ADJ, "N": wn.NOUN, "V": wn.VERB, "R": wn.ADV}
    # Return WordNet POS or default to NOUN if tag is unmapped
    return tag_dict.get(tag, wn.NOUN)

# Calculate Wu-Palmer (WUP) similarity for lexical similarity between predictions and references
def calculate_wup_score(preds, refs):
    # Define helper function to compute WUP similarity for a single pred-ref pair
    def wup_sim(pred, ref):
        # Clean and tokenize prediction and reference text
        pred_tokens = re.sub(r'[^\w\s]', '', pred.lower()).split()
        ref_tokens = re.sub(r'[^\w\s]', '', ref.lower()).split()
        # Return 0 if either token list is empty
        if not pred_tokens or not ref_tokens:
            return 0.0
        # Initialize list to store maximum similarities for prediction tokens
        max_similarities = []
        # Iterate over each prediction token
        for p_token in pred_tokens:
            token_max_sim = 0.0
            # Get synsets for prediction token with POS or fallback to all synsets
            p_synsets = wn.synsets(p_token, pos=get_wordnet_pos(p_token)) or wn.synsets(p_token)
            if not p_synsets:
                continue
            # Iterate over each reference token
            for r_token in ref_tokens:
                # Get synsets for reference token with POS or fallback
                r_synsets = wn.synsets(r_token, pos=get_wordnet_pos(r_token)) or wn.synsets(r_token)
                if not r_synsets:
                    continue
                # Compute WUP similarity for all synset pairs
                token_sims = [wn.wup_similarity(p_syn, r_syn) or 0.0 for p_syn in p_synsets for r_syn in r_synsets]
                if token_sims:
                    # Store maximum similarity for this token pair
                    token_max_sim = max(token_sims)
            if token_max_sim > 0:
                # Store non-zero maximum similarity
                max_similarities.append(token_max_sim)
        # Return average similarity or 0 if no valid similarities
        return sum(max_similarities) / len(max_similarities) if max_similarities else 0.0
    # Compute WUP similarity for all pred-ref pairs
    wup_scores = [wup_sim(p, r) for p, r in zip(preds, refs)]
    # Return average WUP score across all pairs
    return sum(wup_scores) / len(wup_scores) if wup_scores else 0.0

# %% [markdown]
# **Inference**

# %%
preds = [] # Store model predictions
refs  = [] # Store ground-truth answers

BASE_DIR = "/kaggle/input/vrproject2/abo-images-small/images/small"

for i in tqdm(range(0, len(test_df), BATCH_SIZE), desc="Evaluating"):
    batch = test_df.iloc[i : i + BATCH_SIZE]
    images = [
        Image.open(os.path.join(BASE_DIR, fname)).convert("RGB")
        for fname in batch["path"]
    ]
    questions = batch["question"].tolist()

    # Tokenize / preprocess
    inputs = processor(
        images=images,
        text=questions,
        return_tensors="pt",
        padding="max_length",
        truncation=True
    )

    # Move everything to GPU
    inputs = {k: v.to(DEVICE) for k, v in inputs.items()}

    # 3) Generate exactly one token
    with torch.no_grad():
        generated_ids = model.generate(
            **inputs,
            max_new_tokens=1,
            num_beams=5,
            early_stopping=True
        )

    # Decode full answers
    raw_answers = processor.batch_decode(generated_ids, skip_special_tokens=True)
    cleaned_preds = [ans.strip().lower() for ans in raw_answers]

    # Coerce answers to str before strip/lower
    cleaned_refs = [str(r).strip().lower() for r in batch["answer"]]

    cleaned_refs = [number_map.get(r, r) for r in cleaned_refs]

    print(i, cleaned_preds, cleaned_refs)
    
    res = bert_score(cleaned_preds, cleaned_refs, model_type="distilbert-base-uncased")
    
    print(res[0])

    preds.extend(cleaned_preds)
    refs.extend(cleaned_refs)
# Out:
# Evaluating:   0%|          | 0/625 [00:00<?, ?it/s]
# 0 ['it', 'yes', 'oval', 'yes', 'oval', 'no', 'yes', 'leather'] ['brown', 'camera', 'round', 'yes', 'round', 'face', 'lion', 'leather']
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/483 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# tensor([0.7537, 0.6218, 0.7800, 1.0000, 0.7800, 0.7487, 0.6485, 1.0000])
# 8 ['slightly', 'no', 'no', 'no', 'no', 'metal', 'no', 'yes'] ['horizontal', 'triangles', 'landscape', 'yellow', 'suitcase', 'gold', 'green', 'yes']
# tensor([0.7880, 0.7532, 0.7263, 0.7730, 0.7723, 0.8080, 0.7623, 1.0000])
# 16 ['black', 'yes', 'yes', 'yes', 'white', 'woman', 'no', 'yes'] ['black', 'yes', 'car', 'yes', 'white', 'leggings', 'vertical', 'waves']
# tensor([1.0000, 1.0000, 0.6421, 1.0000, 1.0000, 0.6343, 0.7384, 0.6652])
# 24 ['black', 'black', 'yes', 'yes', 'yes', 'yes', '10', 'no'] ['black', 'white', 'yes', 'screen', 'yes', 'no', '10', 'yes']
# tensor([1.0000, 0.8870, 1.0000, 0.6516, 1.0000, 0.8813, 1.0000, 0.8813])
# 32 ['brown', 'no', 'yes', 'leather', 'yes', 'yes', 'rec', 'yes'] ['taupe', 'lbs', 'headphones', 'suede', 'yes', 'yes', 'rectangular', 'necklace']
# tensor([0.6507, 0.7407, 0.6277, 0.7538, 1.0000, 1.0000, 0.7819, 0.6663])
# 40 ['no', 'oval', 'glass', 'oval', 'yes', 'yes', 'yes', 'phone'] ['leaves', 'heart', 'glass', 'round', 'floral', 'yes', 'easy', 'wood']
# tensor([0.7291, 0.7251, 1.0000, 0.7800, 0.6957, 1.0000, 0.7220, 0.7320])
# 48 ['black', 'rec', 'yes', 'blue', '5', 'yes', 'yes', 'no'] ['black', 'rectangular', 'words', 'blue', '3', 'plastic', 'yes', 'yellow']
# tensor([1.0000, 0.7819, 0.7140, 1.0000, 0.7833, 0.6868, 1.0000, 0.7730])
# 56 ['white', 'no', 'white', 'mid', 'oval', 'hands', 'yes', 'rec'] ['white', 'bed', 'black', 'stiletto', 'wisconsin', 'black', 'yes', 'rectangle']
# tensor([1.0000, 0.7338, 0.8870, 0.6404, 0.7033, 0.7215, 1.0000, 0.8009])
# 64 ['left', 'brown', 'oval', 'white', 'no', 'oval', 'rec', 'yes'] ['down', 'brown', 'yin-yang', 'white', 'yellow', 'square', 'rectangular', 'yes']
# tensor([0.7843, 1.0000, 0.6300, 1.0000, 0.7730, 0.8113, 0.7819, 1.0000])
# 72 ['yes', 'yes', 'no', 'round', 'yes', 'rectangular', 'oval', 'yes'] ['diagonal', 'yes', "daddy's", 'round', 'boat', 'square', 'hearts', 'yes']
# tensor([0.6951, 1.0000, 0.7489, 1.0000, 0.6311, 0.8687, 0.7320, 1.0000])
# 80 ['black', 'yes', '2', 'baseball', 'yes', '2', 'metal', 'oval'] ['blue', 'yes', '3', 'usb', 'yes', '2', 'plastic', 'heart']
# tensor([0.8670, 1.0000, 0.8246, 0.7207, 1.0000, 1.0000, 0.8495, 0.7251])
# 88 ['beige', 'no', 'yes', 'yes', 'hands', '0', 'yes', 'yes'] ['oat', 'safety', 'gold', 'necklace', 'sheets', 'thirty', 'floral', 'crystal']
# tensor([0.6647, 0.7558, 0.7181, 0.6663, 0.8419, 0.6684, 0.6957, 0.6846])
# 96 ['yes', 'yes', 'metal', 'blue', 'black', 'black', 'one', 'red'] ['circles', 'yes', 'lace', 'teal', 'black', 'blue', '2', 'red']
# tensor([0.7003, 1.0000, 0.8042, 0.7271, 1.0000, 0.8670, 0.7165, 1.0000])
# 104 ['brown', 'yes', 'white', 'yes', 'yes', 'it', 'yes', 'it'] ['peach', 'yes', 'white', 'yes', 'suede', 'white', 'yes', 'blue']
# tensor([0.7666, 1.0000, 1.0000, 1.0000, 0.6242, 0.7634, 1.0000, 0.7559])
# 112 ['blue', 'yes', 'yes', 'yes', '2', 'white', 'wood', '2'] ['blue', 'rainbow', 'orange', 'panda', '2', 'white', 'wood', '1']
# tensor([1.0000, 0.7013, 0.7137, 0.7092, 1.0000, 1.0000, 1.0000, 0.8405])
# 120 ['no', 'yes', 'no', 'yes', 'phone', 'no', '2', 'yes'] ['no', 'yes', 'snakeskin', 'sunset', 'case', 'wood', '1', 'stars']
# tensor([1.0000, 1.0000, 0.6715, 0.6742, 0.7505, 0.7345, 0.8405, 0.6492])
# 128 ['oval', 'blue', 'blue', 'left', 'yes', 'yes', 'yes', 'yes'] ['octagon', 'white', 'blue', 'forward', 'snake', 'yes', 'yes', 'santa']
# tensor([0.7024, 0.8576, 1.0000, 0.7634, 0.6499, 1.0000, 1.0000, 0.7111])
# 136 ['no', 'it', '0', 'yes', 'yes', 'white', 'yes', 'no'] ['green', 'gold', '3', 'bear', 'chevron', 'white', 'yes', 'red']
# tensor([0.7623, 0.7699, 0.6962, 0.6702, 0.6480, 1.0000, 1.0000, 0.7723])
# 144 ['hand', 'yes', 'wood', 'blue', 'yes', 'no', 'oval', 'no'] ['lamp', 'supergirl', 'wood', 'blue', 'case', 'white', 'round', 'lion']
# tensor([0.8130, 0.5736, 1.0000, 1.0000, 0.6888, 0.7735, 0.7800, 0.7106])
# 152 ['black', 'rectangular', 'yes', 'yes', 'it', 'maroon', 'no', '2'] ['white', 'rectangular', 'plaid', 'yes', 'gold', 'beige', 'brushes', '3']
# tensor([0.8870, 1.0000, 0.7064, 1.0000, 0.7699, 0.8692, 0.7554, 0.8246])
# 160 ['yes', 'yes', 'rectangular', 'blue', 'no', 'no', 'oval', 'purple'] ['yes', 'wooden', 'rectangular', 'navy', 'no', 'blue', 'round', 'purple']
# tensor([1.0000, 0.6908, 1.0000, 0.6733, 1.0000, 0.7789, 0.7800, 1.0000])
# 168 ['rec', 'yes', 'black', 'sandals', 'no', 'yes', 'metal', '6'] ['heart', 'yes', 'silver', 'shoes', 'case', 'yes', 'metal', '2']
# tensor([0.7602, 1.0000, 0.7803, 0.8902, 0.7520, 1.0000, 1.0000, 0.7633])
# 176 ['phone', 'no', 'no', 'yes', 'black', 'yes', 'no', 'no'] ['case', 'yes', 'rectangle', 'gold', 'brown', 'dock', 'glitter', 'sunlight']
# tensor([0.7505, 0.8813, 0.6922, 0.7181, 0.8273, 0.6526, 0.7582, 0.7362])
# 184 ['rec', 'no', '6', 'yes', 'blue', 'yes', 'yes', 'vase'] ['rectangular', 'cartoon', '2', 'marble', 'blue', 'yes', 'abstract', 'plants']
# tensor([0.7819, 0.7480, 0.7633, 0.6783, 1.0000, 1.0000, 0.7007, 0.7395])
# 192 ['yes', 'yes', 'yes', 'yes', 'hand', 'yes', 'yes', 'yes'] ['abstract', 'yes', 'teddy', 'yes', 'crown', 'yes', 'yes', 'black']
# tensor([0.7007, 1.0000, 0.6750, 1.0000, 0.8049, 1.0000, 1.0000, 0.6909])
# 200 ['yes', 'white', 'yes', 'maroon', 'white', '6', 'no', 'it'] ['yes', 'white', 'yes', 'red', 'beige', '2', 'grass', 'orange']
# tensor([1.0000, 1.0000, 1.0000, 0.8263, 0.7927, 0.7633, 0.7297, 0.7812])
# 208 ['yes', 'two', 'black', 'white', 'yes', 'yes', 'yes', 'yes'] ['yes', '1', 'black', 'white', 'gray', 'yes', 'yes', 'you']
# tensor([1.0000, 0.7750, 1.0000, 1.0000, 0.6992, 1.0000, 1.0000, 0.7511])
# 216 ['it', 'no', 'wood', 'yes', 'no', 'it', 'no', '4'] ['gray', 'seascape', 'wood', 'silver', 'orange', 'stacked', 'square', '3']
# tensor([0.7532, 0.6743, 1.0000, 0.6931, 0.7762, 0.7915, 0.7593, 0.8462])
# 224 ['yes', 'blonde', 'yes', 'no', 'no', 'no', 'yes', 'red'] ['yes', 'blonde', 'blue', 'square', 'case', 'black', 'phone', 'red']
# tensor([1.0000, 1.0000, 0.7213, 0.7593, 0.7520, 0.7441, 0.6663, 1.0000])
# 232 ['6', 'it', 'black', '0', 'yes', 'blue', 'oval', 'yes'] ['7', 'green', 'black', '1', 'droplets', 'blue', 'square', 'smiley']
# tensor([0.8588, 0.7331, 1.0000, 0.8181, 0.7053, 1.0000, 0.8113, 0.6951])
# 240 ['yes', '6', 'yes', 'brown', 'long', 'yes', 'maroon', 'yes'] ['yes', '3', 'heart', 'brown', 'silver', 'yes', 'multi-colored', 'case']
# tensor([1.0000, 0.7505, 0.7078, 1.0000, 0.7151, 1.0000, 0.7198, 0.6888])
# 248 ['yes', 'oval', 'hand', 'yes', 'yes', 'rectangular', 'blonde', 'it'] ['heart', 'round', 'vase', 'striped', 'marshmallow', 'state', 'blonde', 'gold']
# tensor([0.7078, 0.7800, 0.7864, 0.7120, 0.6022, 0.6637, 1.0000, 0.7699])
# 256 ['flowers', 'oval', 'black', 'dress', 'yes', '4', 'yes', 'metal'] ['flowers', 'circle', 'black', 'oxfords', 'yes', '3', 'parrot', 'metal']
# tensor([1.0000, 0.8091, 1.0000, 0.6706, 1.0000, 0.8462, 0.6747, 1.0000])
# 264 ['metal', 'no', 'black', 'no', '2', 'white', 'no', 'yes'] ['case', 'white', 'black', 'nickel', '2', 'pink', 'wood', 'yes']
# tensor([0.7468, 0.7735, 1.0000, 0.7799, 1.0000, 0.8224, 0.7345, 1.0000])
# 272 ['oval', 'maroon', 'maroon', 'sneakers', 'yes', 'yes', '2', '6'] ['round', 'purple', 'pink', 'shoes', 'chevron', 'yes', '2', '2']
# tensor([0.7800, 0.8482, 0.8115, 0.8817, 0.6480, 1.0000, 1.0000, 0.7633])
# 280 ['0', 'yes', 'oval', 'silver', 'no', 'hands', 'black', 'no'] ['fifteen', 'yes', 'round', 'silver', 'phone', 'bracelet', 'black', 'desk']
# tensor([0.6355, 1.0000, 0.7800, 1.0000, 0.7263, 0.8034, 1.0000, 0.7290])
# 288 ['yes', 'yes', 'yes', 'rectangular', 'it', 'yes', 'white', 'metal'] ['pink', 'crown', 'yes', 'rectangular', 'forward', 'no', 'silver', 'silver']
# tensor([0.6968, 0.6727, 1.0000, 1.0000, 0.7429, 0.8813, 0.8049, 0.8339])
# 296 ['white', 'yes', '6', '0', 'yes', 'it', 'no', 'no'] ['white', 'white', '5', '1', 'yes', 'multicolor', 'yes', 'bedroom']
# tensor([1.0000, 0.6923, 0.8520, 0.8181, 1.0000, 0.6556, 0.8813, 0.7470])
# 304 ['yes', 'yes', '6', 'yes', 'no', 'yes', 'blue', 'metal'] ['yes', 'unknown', '3', 'mandala', 'brown', 'shoes', 'orange', 'metal']
# tensor([1.0000, 0.6804, 0.7505, 0.5894, 0.7460, 0.6678, 0.8530, 1.0000])
# 312 ['0', 'no', 'no', 'yes', 'no', 'no', 'blue', 'no'] ['1', 'phone', 'yes', 'moon', 'vertical', 'no', 'blue', 'nan']
# tensor([0.8181, 0.7263, 0.8813, 0.6816, 0.7384, 1.0000, 1.0000, 0.7800])
# 320 ['yes', 'blue', '2', 'yes', 'yes', 'metal', 'no', 'oval'] ['yes', 'pink', '3', 'yes', 'yes', 'plastic', 'stars', 'round']
# tensor([1.0000, 0.8547, 0.8246, 1.0000, 1.0000, 0.8495, 0.7251, 0.7800])
# 328 ['yes', 'black', 'yes', '1', 'trees', 'yes', 'black', 'yes'] ['yes', 'black', 'no', '1', 'landscape', 'yes', 'black', 'bricks']
# tensor([1.0000, 1.0000, 0.8813, 1.0000, 0.7937, 1.0000, 1.0000, 0.6903])
# 336 ['yes', 'black', 'yes', 'yes', 'dark', 'no', 'yes', '6'] ['yes', 'black', 'yes', 'crystal', 'pink', 'black', 'yes', '3']
# tensor([1.0000, 1.0000, 1.0000, 0.6846, 0.7777, 0.7441, 1.0000, 0.7505])
# 344 ['4', 'maroon', '2', 'yes', 'oval', 'yes', 'wood', 'phone'] ['4', 'brown', '2', 'pink', 'round', 'yes', 'wood', 'phone']
# tensor([1.0000, 0.8232, 1.0000, 0.6968, 0.7800, 1.0000, 1.0000, 1.0000])
# 352 ['no', 'no', 'white', 'yes', 'light', 'oval', 'no', '2'] ['square', 'stripes', 'white', 'blue', 'light', 'circle', 'case', '2']
# tensor([0.7593, 0.7625, 1.0000, 0.7213, 1.0000, 0.8091, 0.7520, 1.0000])
# 360 ['yes', 'white', '2', 'yes', '6', 'yes', 'white', 'no'] ['yes', 'white', '3', 'pink', '4', 'phone', 'white', 'denim']
# tensor([1.0000, 1.0000, 0.8246, 0.6968, 0.8080, 0.6663, 1.0000, 0.7428])
# 368 ['lamp', 'no', 'yes', 'yes', 'no', 'hand', 'sneakers', 'oval'] ['lamp', 'croc', 'yes', 'yes', 'stars', 'sofa', 'shoes', 'floral']
# tensor([1.0000, 0.6757, 1.0000, 1.0000, 0.7251, 0.7803, 0.8817, 0.7916])
# 376 ['black', 'yes', '2', 'yes', 'purple', 'yes', '0', '2'] ['cyan', 'you', '2', 'yes', 'purple', 'flowers', '1', '4']
# tensor([0.7197, 0.7511, 1.0000, 1.0000, 1.0000, 0.6006, 0.8181, 0.7995])
# 384 ['black', 'legs', 'no', 'no', 'no', '0', 'yes', 'no'] ['blue', 'arms', 'bow', 'no', 'pocket', '5', 'abstract', 'cellular']
# tensor([0.8670, 0.7926, 0.7756, 1.0000, 0.7773, 0.7043, 0.7007, 0.7597])
# 392 ['no', '10', 'two', 'no', 'yes', 'blue', '6', 'no'] ['vertical', '4', '3', 'blue', 'geometric', 'red', '6', 'chain']
# tensor([0.7384, 0.7463, 0.7364, 0.7789, 0.7141, 0.8734, 1.0000, 0.7693])
# 400 ['yes', 'yes', 'white', 'white', 'yes', 'no', 'yes', 'yes'] ['red', 'yes', 'dark', 'black', 'hearts', 'designed', 'yes', 'yes']
# tensor([0.7188, 1.0000, 0.7722, 0.8870, 0.7353, 0.6628, 1.0000, 1.0000])
# 408 ['rectangular', 'blue', 'no', 'vase', 'rec', '6', 'yes', 'yes'] ['square', 'blue', 'bunk', 'lamp', 'rectangle', '4', 'yes', 'fabric']
# tensor([0.8687, 1.0000, 0.7678, 0.8532, 0.8009, 0.8080, 1.0000, 0.6568])
# 416 ['hand', 'black', '5', 'yes', 'yes', 'black', 'no', 'yes'] ['gravel', 'black', '3', 'earrings', 'heart', 'yellow', 'yes', 'yes']
# tensor([0.7315, 1.0000, 0.7833, 0.6803, 0.7078, 0.8540, 0.8813, 1.0000])
# 424 ['yes', 'ten', 'metal', '2', 'yes', 'maroon', 'mid', '2'] ['phone', '9', 'denim', '2', 'yes', 'red', 'high', '2']
# tensor([0.6663, 0.7616, 0.7927, 1.0000, 1.0000, 0.8263, 0.7955, 1.0000])
# 432 ['metal', 'white', 'brown', 'hand', 'yes', 'black', 'white', 'no'] ['metal', 'white', 'brown', 'clock', 'yes', 'charcoal', 'beige', 'phone']
# tensor([1.0000, 1.0000, 1.0000, 0.7965, 1.0000, 0.7693, 0.7927, 0.7263])
# 440 ['no', 'maroon', 'metal', 'no', 'no', 'no', 'yes', '2'] ['phone', 'multicolor', 'metal', 'vertical', 'no', 'beige', 'yes', '2']
# tensor([0.7263, 0.7205, 1.0000, 0.7384, 1.0000, 0.7907, 1.0000, 1.0000])
# 448 ['yes', 'almond', 'yes', 'trees', 'yellow', 'no', 'yes', 'black'] ['yes', 'buckle', 'shoe', 'forest', 'yellow', 'butterfly', 'maybe', 'black']
# tensor([1.0000, 0.8472, 0.6752, 0.8537, 1.0000, 0.6964, 0.7345, 1.0000])
# 456 ['forward', 'no', 'yes', 'no', 'yes', 'no', 'yes', 'no'] ['diagonal', 'pink', 'tuk-tuks', 'yes', 'smile', 'vertical', 'pink', 'case']
# tensor([0.7825, 0.7590, 0.6261, 0.8813, 0.7127, 0.7384, 0.6968, 0.7520])
# 464 ['0', 'oval', 'blue', 'yes', 'yes', 'yes', 'almond', 'yes'] ['3', 'square', 'blue', 'necklace', 'suede', 'characters', 'velcro', 'yes']
# tensor([0.6962, 0.8113, 1.0000, 0.6663, 0.6242, 0.6445, 0.6742, 1.0000])
# 472 ['metal', '2', 'no', 'yes', 'yes', 'curved', 'white', 'yes'] ['others', '1', 'white', 'purple', 'no', 'bowtie', 'black', 'yes']
# tensor([0.7299, 0.8405, 0.7735, 0.6769, 0.8813, 0.7018, 0.8870, 1.0000])
# 480 ['black', 'black', 'yes', '2', 'no', 'hand', 'oval', '5'] ['white', 'black', 'yes', '2', 'magic', 'phone', 'heart', '2']
# tensor([0.8870, 1.0000, 1.0000, 1.0000, 0.7664, 0.7912, 0.7251, 0.7655])
# 488 ['white', 'yes', 'metal', 'yes', 'yes', 'female', 'white', 'yes'] ['lavender', 'yes', 'metal', 'yes', 'black', 'both', 'grey', 'rough']
# tensor([0.7830, 1.0000, 1.0000, 1.0000, 0.6909, 0.6325, 0.8388, 0.7015])
# 496 ['green', 'it', '6', 'metal', 'yes', 'no', 'white', '6'] ['white', 'blue', '4', 'rocks', 'yes', 'yellow', 'white', '2']
# tensor([0.8257, 0.7559, 0.8080, 0.8191, 1.0000, 0.7730, 1.0000, 0.7633])
# 504 ['no', 'yes', 'hand', 'no', 'black', 'it', 'hand', 'yes'] ['leather', 'shoe', 'police', 'blue', 'black', 'brown', 'shelf', 'no']
# tensor([0.7513, 0.6752, 0.6931, 0.7789, 1.0000, 0.7537, 0.7805, 0.8813])
# 512 ['no', 'oval', 'white', 'yes', 'sky', 'yes', '6', 'red'] ['love', 'rectangular', 'white', 'queen', 'trees', 'yes', '3', 'red']
# tensor([0.7425, 0.8418, 1.0000, 0.6889, 0.7480, 1.0000, 0.7505, 1.0000])
# 520 ['yes', 'yes', 'yes', '5', 'rec', 'no', 'no', 'rec'] ['bow', 'yes', 'yes', '3', 'squares', 'no', 'case', 'rectangular']
# tensor([0.7359, 1.0000, 1.0000, 0.7833, 0.7910, 1.0000, 0.7520, 0.7819])
# 528 ['yes', 'no', 'yes', 'yes', 'it', 'yes', 'yes', '2'] ['pink', 'girl', 'ring', 'stars', 'orange', 'rectangle', 'auto', '2']
# tensor([0.6968, 0.7588, 0.6484, 0.6492, 0.7812, 0.6393, 0.6891, 1.0000])
# 536 ['it', 'no', 'no', 'yes', 'white', 'blue', 'white', 'black'] ['silver', 'yes', 'fabric', 'headphones', 'white', 'blue', 'white', 'black']
# tensor([0.7527, 0.8813, 0.7331, 0.6277, 1.0000, 1.0000, 1.0000, 1.0000])
# 544 ['yes', 'no', 'yes', 'no', 'no', 'beige', 'hand', 'rec'] ['yes', 'matte', 'animal', 'stripes', 'smooth', 'blush', 'dolls', 'hearts']
# tensor([1.0000, 0.7323, 0.6486, 0.7625, 0.7861, 0.8753, 0.7733, 0.7583])
# 552 ['yes', 'black', 'yes', 'tan', 'no', 'no', '2', '0'] ['star', 'black', 'yes', 'beige', 'laundry', 'yellow', '1', '1']
# tensor([0.6446, 1.0000, 1.0000, 0.7738, 0.7535, 0.7730, 0.8405, 0.8181])
# 560 ['yes', 'yes', 'yes', 'no', 'yes', '2', 'yes', 'yes'] ['stars', 'multicolor', 'lights', 'floral', 'yes', '3', 'yes', 'blue']
# tensor([0.6492, 0.6242, 0.6568, 0.7728, 1.0000, 0.8246, 1.0000, 0.7213])
# 568 ['yes', 'yes', 'hand', 'black', 'yes', 'round', 'yes', 'maroon'] ['chevron', 'yes', 'table', 'black', 'woman', 'round', 'yes', 'orange']
# tensor([0.6480, 1.0000, 0.8077, 1.0000, 0.6981, 1.0000, 1.0000, 0.8193])
# 576 ['no', 'yes', 'yes', 'yes', 'one', 'yes', 'mountains', 'no'] ['no', 'rope', 'yes', 'pink', '1', 'yes', 'scenery', 'glitter']
# tensor([1.0000, 0.6709, 1.0000, 0.6968, 0.8568, 1.0000, 0.8015, 0.7582])
# 584 ['no', 'yes', 'hands', 'brown', 'white', 'no', 'white', 'maroon'] ['circular', 'yes', 'chain', 'brown', 'orange', 'clutch', 'gray', 'red']
# tensor([0.7631, 1.0000, 0.7955, 1.0000, 0.8364, 0.7393, 0.8108, 0.8263])
# 592 ['red', 'yes', 'yes', 'hands', 'yes', 'no', 'yes', 'green'] ['red', 'rock', 'pink', 'phone', 'yellow', 'cracked', 'yes', 'green']
# tensor([1.0000, 0.7232, 0.6968, 0.7650, 0.7170, 0.7920, 1.0000, 1.0000])
# 600 ['yes', 'yes', 'blue', 'no', 'yes', 'yes', 'yes', 'yes'] ['pink', 'yes', 'blue', 'suitcase', 'case', 'star', 'yes', 'yes']
# tensor([0.6968, 1.0000, 1.0000, 0.7723, 0.6888, 0.6446, 1.0000, 1.0000])
# 608 ['hand', 'yes', 'yes', 'yes', 'white', 'white', 'yes', 'hand'] ['bracelet', 'pink', 'no', 'yes', 'white', 'white', 'yes', 'case']
# tensor([0.8126, 0.6968, 0.8813, 1.0000, 1.0000, 1.0000, 1.0000, 0.7814])
# 616 ['tan', 'metal', 'sunlight', '2', 'blue', 'black', 'yes', 'white'] ['orange', 'metal', 'sun', '3', 'navy', 'black', 'yes', 'gold']
# tensor([0.7806, 1.0000, 0.8795, 0.8246, 0.6733, 1.0000, 1.0000, 0.8153])
# 624 ['yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'left', 'green'] ['pan', 'yes', 'pink', 'yes', 'yes', 'paint', 'up', 'green']
# tensor([0.7390, 1.0000, 0.6968, 1.0000, 1.0000, 0.7138, 0.7689, 1.0000])
# 632 ['yes', 'yes', 'oval', 'white', 'black', 'oval', 'yes', 'no'] ['yes', 'yes', 'circle', 'pink', 'black', 'oval', 'yes', 'case']
# tensor([1.0000, 1.0000, 0.8091, 0.8224, 1.0000, 1.0000, 1.0000, 0.7520])
# 640 ['yes', 'yes', '2', 'yes', 'yes', 'no', '2', 'yes'] ['black', 'red', '1', 'yes', 'pink', 'case', '3', 'yes']
# tensor([0.6909, 0.7188, 0.8405, 1.0000, 0.6968, 0.7520, 0.8246, 1.0000])
# 648 ['yes', 'oval', 'woman', 'no', 'yes', 'black', 'no', 'no'] ['mirror', 'cone', 'text', 'cellular', 'yes', 'black', 'black', 'unicorn']
# tensor([0.6922, 0.8000, 0.7636, 0.7597, 1.0000, 1.0000, 0.7441, 0.7529])
# 656 ['yes', 'white', 'yes', 'blue', '6', 'no', 'black', 'no'] ['case', 'orange', 'yes', 'blue', '3', 'yes', 'black', 'dress']
# tensor([0.6888, 0.8364, 1.0000, 1.0000, 0.7505, 0.8813, 1.0000, 0.7332])
# 664 ['no', 'yes', 'oval', 'no', '0', 'yes', '2', '0'] ['indoors', 'black', 'circle', 'abstract', 'green', 'elephant', 'thirty-two', '1']
# tensor([0.7188, 0.6909, 0.8091, 0.7677, 0.6642, 0.6623, 0.6368, 0.8181])
# 672 ['2', 'hands', 'no', '2', 'yes', 'yes', 'no', 'no'] ['2', 'holding', 'case', '2', 'no', 'yes', 'phone', 'left']
# tensor([1.0000, 0.8245, 0.7520, 1.0000, 0.8813, 1.0000, 0.7263, 0.8029])
# 680 ['no', 'metal', 'black', 'yes', 'yes', 'no', '2', 'yes'] ['case', 'metal', 'black', 'skm', 'case', 'usb', '2', 'phone']
# tensor([0.7520, 1.0000, 1.0000, 0.6682, 0.6888, 0.7393, 1.0000, 0.6663])
# 688 ['yes', 'yes', 'almond', 'black', 'yes', 'yes', 'yes', 'oval'] ['yes', 'yes', 'metal', 'silver', 'yes', 'u', 'swimming', 'hearts']
# tensor([1.0000, 1.0000, 0.7416, 0.7803, 1.0000, 0.7019, 0.6478, 0.7320])
# 696 ['rec', 'brown', 'yes', 'no', 'it', 'yes', '2', 'cylinder'] ['rectangle', 'tan', 'lightbulb', 'suitcase', 'black', 'yes', '1', 'cylindrical']
# tensor([0.8009, 0.7875, 0.5545, 0.7723, 0.7439, 1.0000, 0.8405, 0.8868])
# 704 ['oval', 'white', 'oval', '5', 'wood', 'black', 'yes', 'yes'] ['circle', 'yellow', 'heart', '3', 'wood', 'white', 'yes', 'no']
# tensor([0.8091, 0.8761, 0.7251, 0.7833, 1.0000, 0.8870, 1.0000, 0.8813])
# 712 ['yes', 'yes', 'one', 'red', 'no', 'yes', 'no', 'yes'] ['yes', 'yes', '2', 'pink', 'no', 'yes', 'yes', 'yes']
# tensor([1.0000, 1.0000, 0.7165, 0.8545, 1.0000, 1.0000, 0.8813, 1.0000])
# 720 ['oval', 'no', 'yes', 'yes', 'metal', 'yes', 'no', 'rectangular'] ['heart', 'case', 'necklace', 'abstract', 'metal', 'red', 'laces', 'square']
# tensor([0.7251, 0.7520, 0.6663, 0.7007, 1.0000, 0.7188, 0.6490, 0.8687])
# 728 ['ten', 'curved', 'white', '6', 'yes', 'yes', 'yes', 'no'] ['vi', 'curved', 'white', '2', 'whale', 'yes', 'swirl', 'yes']
# tensor([0.7014, 1.0000, 1.0000, 0.7633, 0.6168, 1.0000, 0.7344, 0.8813])
# 736 ['hand', 'no', 'two', 'blue', 'closed', 'no', 'yes', '1'] ['bracelet', 'empty', '2', 'magenta', 'horizontal', 'boats', 'yes', '1']
# tensor([0.8126, 0.7932, 0.8447, 0.7321, 0.7153, 0.6826, 1.0000, 1.0000])
# 744 ['no', 'tan', 'yes', 'yes', 'yes', 'metal', 'yes', '2'] ['fabric', 'brown', 'flowers', 'yes', 'red', 'silver', 'light', '4']
# tensor([0.7331, 0.7875, 0.6006, 1.0000, 0.7188, 0.8339, 0.6582, 0.7995])
# 752 ['no', 'yes', 'yes', 'no', 'oval', 'yes', 'no', 'black'] ['white', 'no', 'yes', 'no', 'round', 'abstract', 'grey', 'black']
# tensor([0.7735, 0.8813, 1.0000, 1.0000, 0.7800, 0.7007, 0.7553, 1.0000])
# 760 ['yes', 'yes', 'blue', 'yes', 'no', 'yes', 'yes', 'yes'] ['kitty', 'yes', 'blue', 'chair', 'green', 'r', 'yes', 'yes']
# tensor([0.7002, 1.0000, 1.0000, 0.7166, 0.7623, 0.6707, 1.0000, 1.0000])
# 768 ['10', 'curved', 'yes', 'yes', 'hand', '2', 'hand', 'yes'] ['8', 'rounded', 'teal', 'yes', 'headphones', '3', 'orange', 'yes']
# tensor([0.8217, 0.9032, 0.6734, 1.0000, 0.6968, 0.8246, 0.7748, 1.0000])
# 776 ['oval', 'oval', 'yes', 'oval', 'yes', '2', 'yes', 'it'] ['round', 'apple', 'handle', 'round', 'bed', '3', 'home', 'brown']
# tensor([0.7800, 0.7125, 0.7123, 0.7800, 0.7021, 0.8246, 0.7138, 0.7537])
# 784 ['blue', 'yes', 'white', 'ten', 'yes', 'no', 'black', 'yes'] ['blue', 'yes', 'white', '5', 'yes', 'gray', 'brown', 'yes']
# tensor([1.0000, 1.0000, 1.0000, 0.7012, 1.0000, 0.7573, 0.8273, 1.0000])
# 792 ['yes', 'oval', '6', 'yes', 'yes', 'yes', 'no', 'white'] ['yes', 'heart', '2', 'pink', 'umbrella', 'lions', 'lightbulbs', 'grey']
# tensor([1.0000, 0.7251, 0.7633, 0.6968, 0.7061, 0.6438, 0.6752, 0.8388])
# 800 ['yes', 'yes', 'yes', 'yes', 'no', 'yes', 'no', 'no'] ['yes', 'yes', 'pink', 'yes', 'accessory', 'yes', 'food', 'triangle']
# tensor([1.0000, 1.0000, 0.6968, 1.0000, 0.7730, 1.0000, 0.7255, 0.7216])
# 808 ['no', 'yes', 'triangle', 'oval', 'yes', 'it', 'white', 'yes'] ['phone', 'yes', 'triangle', 'square', 'case', 'yellow', 'white', 'yes']
# tensor([0.7263, 1.0000, 1.0000, 0.8113, 0.6888, 0.7399, 1.0000, 1.0000])
# 816 ['it', 'oval', 'left', 'pink', 'yes', 'yes', 'white', 'yes'] ['pink', 'heart', 'pink', 'pink', 'abstract', 'red', 'white', 'yes']
# tensor([0.7610, 0.7251, 0.7633, 1.0000, 0.7007, 0.7188, 1.0000, 1.0000])
# 824 ['no', 'yes', 'yes', 'yes', 'oval', 'no', 'black', 'yes'] ['plastic', 'yes', 'yes', 'necklace', 'round', 'white', 'black', 'paint']
# tensor([0.7482, 1.0000, 1.0000, 0.6663, 0.7800, 0.7735, 1.0000, 0.7138])
# 832 ['yes', 'green', 'yes', 'yes', 'yes', 'hand', 'yes', 'yes'] ['yes', 'green', 'wheels', 'swirls', 'cat', 'sofa', 'yes', 'shapes']
# tensor([1.0000, 1.0000, 0.6540, 0.6679, 0.7022, 0.7803, 1.0000, 0.7173])
# 840 ['no', 'sandals', 'no', 'blue', 'metal', 'two', '5', '2'] ['yellow', 'sandals', 'phone', 'blue', 'metal', '1', '3', '7']
# tensor([0.7730, 1.0000, 0.7263, 1.0000, 1.0000, 0.7750, 0.7833, 0.7252])
# 848 ['no', 'black', 'yes', 'yes', 'yes', 'curved', 'man', 'wood'] ['abstract', 'grey', 'yes', 'yes', 'n', 'wedge', 'shoes', 'wood']
# tensor([0.7677, 0.8490, 1.0000, 1.0000, 0.7235, 0.8813, 0.7340, 1.0000])
# 856 ['oval', 'yes', 'no', 'oval', '2', 'green', 'yes', 'white'] ['round', 'yes', 'case', 'cylindrical', '1', 'green', 'yellow', 'white']
# tensor([0.7800, 1.0000, 0.7520, 0.8102, 0.8405, 1.0000, 0.7170, 1.0000])
# 864 ['no', 'yes', 'no', 'oval', 'black', 'no', 'no', 'yes'] ['diagonal', 'yes', 'waste', 'round', 'black', 'brown', 'union', 'yes']
# tensor([0.7541, 1.0000, 0.6913, 0.7800, 1.0000, 0.7460, 0.7061, 1.0000])
# 872 ['no', 'yes', 'black', 'black', 'yes', 'oval', 'white', 'oval'] ['case', 'yes', 'white', 'silver', 'case', 'circular', 'black', 'round']
# tensor([0.7520, 1.0000, 0.8870, 0.7803, 0.6888, 0.8544, 0.8870, 0.7800])
# 880 ['yes', 'yes', 'rec', '0', 'hand', 'no', 'yes', 'no'] ['owl', 'yes', 'rectangular', 'twelve', 'dresser', 'case', 'panda', 'white']
# tensor([0.6359, 1.0000, 0.7819, 0.6305, 0.7706, 0.7520, 0.7092, 0.7735])
# 888 ['yes', '1', 'white', 'yes', 'no', 'yes', 'blue', 'yes'] ['yes', '1', 'beige', 'yes', 'paper', 'apple', 'pink', 'silver']
# tensor([1.0000, 1.0000, 0.7927, 1.0000, 0.7517, 0.6424, 0.8547, 0.6931])
# 896 ['maroon', 'metal', 'yes', 'yes', 'black', 'yes', '5', 'yes'] ['rainbow', 'leather', 'case', 'green', 'gray', 'abstract', '3', 'amazonbasics']
# tensor([0.8363, 0.8524, 0.6888, 0.6771, 0.8042, 0.7007, 0.7833, 0.6257])
# 904 ['yes', 'hand', '0', 'it', '2', 'white', 'white', 'yes'] ['yes', 'case', '2', 'brown', '2', 'white', 'white', 'multi']
# tensor([1.0000, 0.7814, 0.7515, 0.7537, 1.0000, 1.0000, 1.0000, 0.7299])
# 912 ['yes', 'yes', 'yes', 'no', 'legs', 'yes', 'hand', 'white'] ['yes', 'yes', 'yes', 'brown', 'wire', 'a', 'phone', 'black']
# tensor([1.0000, 1.0000, 1.0000, 0.7460, 0.7405, 0.7561, 0.7912, 0.8870])
# 920 ['no', 'man', '0', 'closed', '10', '2', 'white', 'no'] ['phone', 'black', '1', 'laces', 'many', '2', 'black', 'blue']
# tensor([0.7263, 0.7331, 0.8181, 0.6516, 0.6989, 1.0000, 0.8870, 0.7789])
# 928 ['white', 'yes', 'no', 'yes', 'it', 'maroon', 'yes', 'yes'] ['white', 'yes', 'green', 'purple', 'gray', 'black', 'grey', 'multicolor']
# tensor([1.0000, 1.0000, 0.7623, 0.6769, 0.7532, 0.8170, 0.6876, 0.6242])
# 936 ['white', 'rec', 'no', 'yes', 'no', 'oval', 'no', 'yes'] ['grey', 'rectangle', 'sandal', 'yes', 'cellular', 'apple', 'woodgrain', 'gray']
# tensor([0.8388, 0.8009, 0.7046, 1.0000, 0.7597, 0.7125, 0.6397, 0.6992])
# 944 ['black', '2', 'no', 'yes', '2', 'yes', 'heels', 'no'] ['black', '2', 'water', 'grey', '0', 'repeating', 'shoes', 'yes']
# tensor([1.0000, 1.0000, 0.7403, 0.6876, 0.7515, 0.7078, 0.8956, 0.8813])
# 952 ['woman', 'yes', 'yes', '2', 'no', 'yes', 'white', 'oval'] ['shoes', 'phone', 'yes', '3', 'pillow', 'grid', 'yellow', 'round']
# tensor([0.7351, 0.6663, 1.0000, 0.8246, 0.7505, 0.6585, 0.8761, 0.7800])
# 960 ['yes', 'blue', 'yes', 'almond', 'blue', 'blue', 'it', 'oval'] ['plastic', 'blue', 'yes', 'plastic', 'blue', 'blue', 'colorful', 'round']
# tensor([0.6868, 1.0000, 1.0000, 0.8017, 1.0000, 1.0000, 0.8024, 0.7800])
# 968 ['yes', 'long', 'rectangular', 'hand', 'yes', 'yes', 'yes', '0'] ['yes', 'string', 'rectangle', 'box', 'uniform', 'yes', 'towels', 'twelve']
# tensor([1.0000, 0.7427, 0.8180, 0.7839, 0.6737, 1.0000, 0.6958, 0.6305])
# 976 ['yes', 'yes', 'yes', '5', 'no', 'ten', 'oval', 'trees'] ['yes', 'yes', 'polka', '2', 'plant', '6', 'hoop', 'snow']
# tensor([1.0000, 1.0000, 0.6527, 0.7655, 0.6863, 0.6809, 0.7851, 0.7604])
# 984 ['flowers', 'chain', 'no', 'no', 'yes', 'no', 'yes', '2'] ['birds', 'pendant', 'velvet', 'corner', 'yes', 'bowl', 'plastic', '2']
# tensor([0.7730, 0.8782, 0.7596, 0.7321, 1.0000, 0.7660, 0.6868, 1.0000])
# 992 ['no', '2', '1', 'no', 'curved', 'yes', 'no', 'white'] ['rose', '2', '3', 'yes', 'curved', 'yes', 'love', 'white']
# tensor([0.7362, 1.0000, 0.8201, 0.8813, 1.0000, 1.0000, 0.7425, 1.0000])
# 1000 ['chain', 'one', 'hand', 'it', 'yes', 'no', 'yes', 'yes'] ['teacup', '1', 'wallet', 'teal', 'fabric', 'swirl', 'yes', 'gold']
# tensor([0.7082, 0.8568, 0.8081, 0.7365, 0.6568, 0.7870, 1.0000, 0.7181])
# 1008 ['yes', 'yes', 'no', 'maroon', 'yes', 'no', 'no', '2'] ['yes', 'yes', 'no', 'purple', 'yes', 'fur', 'yes', '2']
# tensor([1.0000, 1.0000, 1.0000, 0.8482, 1.0000, 0.7528, 0.8813, 1.0000])
# 1016 ['yes', 'yes', 'yes', 'long', 'it', 'no', 'yes', 'yes'] ['yes', 'fabric', 'tree', 'fine', 'brown', 'yes', 'yes', 'oil']
# tensor([1.0000, 0.6568, 0.6230, 0.8051, 0.7537, 0.8813, 1.0000, 0.6500])
# 1024 ['oval', 'yes', 'curved', 'yes', 'yes', 'brown', 'black', 'boots'] ['round', 'libra', 't', 'butterfly', 'yes', 'brown', 'black', 'boot']
# tensor([0.7800, 0.6071, 0.7110, 0.6171, 1.0000, 1.0000, 1.0000, 0.8990])
# 1032 ['black', 'rec', 'yes', 'silver', 'yes', 'yes', 'yes', 'no'] ['black', 'rectangular', 'yes', 'silver', 'yes', 'text', 'yes', 'vertical']
# tensor([1.0000, 0.7819, 1.0000, 1.0000, 1.0000, 0.6771, 1.0000, 0.7384])
# 1040 ['black', 'rec', '0', 'yes', 'yes', 'curved', '4', 'yes'] ['black', 'rectangle', '2', 'yes', 'case', 'oval', '2', 'heart']
# tensor([1.0000, 0.8009, 0.7515, 1.0000, 0.6888, 0.8041, 0.7995, 0.7078])
# 1048 ['rec', 'yes', 'yes', 'wood', 'no', 'round', 'yes', 'no'] ['rectangular', 'i', 'yes', 'wood', 'spots', 'square', 'solmo', 'case']
# tensor([0.7819, 0.7643, 1.0000, 1.0000, 0.7544, 0.7789, 0.6962, 0.7520])
# 1056 ['2', 'yes', 'rec', 'yes', 'no', 'no', '2', 'yes'] ['2', 'yes', 'rectangle', 'case', 'yellow', 'owls', '2', 'cat']
# tensor([1.0000, 1.0000, 0.8009, 0.6888, 0.7730, 0.7161, 1.0000, 0.7022])
# 1064 ['yes', 'round', 'yes', 'yes', 'yes', 'yes', 'vertically', 'it'] ['yes', 'round', 'bead', 'pink', 'no', 'stripes', 'horizontal', 'yellow']
# tensor([1.0000, 1.0000, 0.6844, 0.6968, 0.8813, 0.6945, 0.9165, 0.7399])
# 1072 ['no', '2', 'no', 'yes', 'oval', 'yes', 'no', 'silver'] ['yes', '5', 'case', 'orange', 'square', 'yes', 'rectangle', 'silver']
# tensor([0.8813, 0.7655, 0.7520, 0.7137, 0.8113, 1.0000, 0.6922, 1.0000])
# 1080 ['white', 'rec', 'yes', 'yes', 'yes', 'black', 'yes', 'black'] ['white', 'square', 'butterflies', 'no', 'v', 'black', 'earrings', 'blue']
# tensor([1.0000, 0.7615, 0.6117, 0.8813, 0.6905, 1.0000, 0.6803, 0.8670])
# 1088 ['yes', 'yes', 'white', 'glasses', 'dark', 'yes', 'blue', 'yes'] ['yes', 'yes', 'white', 'glasses', 'dark', 'glasses', 'multicolor', 'yes']
# tensor([1.0000, 1.0000, 1.0000, 1.0000, 1.0000, 0.6685, 0.7295, 1.0000])
# 1096 ['yes', 'white', '6', 'white', 'oval', 'rec', 'yes', 'yes'] ['yes', 'white', 'many', 'white', 'round', 'rectangular', 'red', 'yes']
# tensor([1.0000, 1.0000, 0.6875, 1.0000, 0.7800, 0.7819, 0.7188, 1.0000])
# 1104 ['black', 'yes', 'yes', 'no', 'yes', 'white', 'rec', 'no'] ['black', 'camera', 'yes', 'rectangular', 'pink', 'pink', 'rectangle', 'glitter']
# tensor([1.0000, 0.6218, 1.0000, 0.7726, 0.6968, 0.8224, 0.8009, 0.7582])
# 1112 ['maroon', 'yes', 'white', 'yes', 'black', 'yes', 'black', 'yes'] ['black', 'yes', 'white', 'light', 'black', 'yes', 'black', 'yes']
# tensor([0.8170, 1.0000, 1.0000, 0.6582, 1.0000, 1.0000, 1.0000, 1.0000])
# 1120 ['yes', 'yes', 'metal', 'oval', 'yes', '6', 'black', 'yes'] ['pomegranate', 'amazonbasics', 'metal', 'circle', 'yes', '3', 'blue', 'pink']
# tensor([0.6164, 0.6257, 1.0000, 0.8091, 1.0000, 0.7505, 0.8670, 0.6968])
# 1128 ['yes', 'yes', 'black', 'yes', 'yes', 'yes', 'yes', 'forward'] ['silver', 'yes', 'black', 'huawei', 'no', 'yes', 'flowers', 'left']
# tensor([0.6931, 1.0000, 1.0000, 0.5510, 0.8813, 1.0000, 0.6006, 0.7634])
# 1136 ['no', 'yes', 'oval', 'no', '4', '1', 'yes', 'yes'] ['backpack', 'boss', 'cylindrical', 'case', '3', '1', 'pink', 'dog']
# tensor([0.7585, 0.7380, 0.8102, 0.7520, 0.8462, 1.0000, 0.6968, 0.6419])
# 1144 ['2', 'white', 'black', 'no', 'it', 'blue', 'no', 'yes'] ['7', 'purple', 'grey', 'yellow', 'yellow', 'yellow', 'solimo', 'yes']
# tensor([0.7252, 0.8287, 0.8490, 0.7730, 0.7399, 0.8811, 0.6836, 1.0000])
# 1152 ['metal', 'yes', 'black', 'yes', 'yes', 'yes', 'oval', '2'] ['metal', 'yes', 'black', 'yes', 'yes', 'fruit', 'oval', '1']
# tensor([1.0000, 1.0000, 1.0000, 1.0000, 1.0000, 0.6067, 1.0000, 0.8405])
# 1160 ['no', 'yes', '0', 'black', 'no', 'yes', 'yes', 'black'] ['tree', 'yes', 'camo', 'black', 'stripes', 'orange', 'keyboard', 'black']
# tensor([0.6977, 1.0000, 0.6623, 1.0000, 0.7625, 0.7137, 0.6738, 1.0000])
# 1168 ['no', 'rec', 'yes', 'yes', 'no', 'maroon', 'metal', 'no'] ['no', 'rectangle', 'heart', 'hearts', 'blue', 'daddys', 'wood', 'grey']
# tensor([1.0000, 0.8009, 0.7078, 0.7353, 0.7789, 0.6942, 0.8157, 0.7553])
# 1176 ['no', 'yes', 'metal', 'yes', 'no', 'no', 'black', 'no'] ['solmo', 'yes', 'metal', 'pink', 'diagonal', 'no', 'black', 'goose']
# tensor([0.7356, 1.0000, 1.0000, 0.6968, 0.7541, 1.0000, 1.0000, 0.7766])
# 1184 ['oval', 'yes', '4', 'yes', 'yes', 'yes', 'yes', 'no'] ['oval', 'scorpio', '4', 'sheets', 'cat', 'rocket', 'car', 'no']
# tensor([1.0000, 0.6428, 1.0000, 0.7084, 0.7022, 0.6892, 0.6421, 1.0000])
# 1192 ['yes', 'yes', 'one', 'no', 'faded', 'no', 'no', 'maroon'] ['purple', 'fabric', '1', 'jar', 'light', 'glitter', 'no', 'brown']
# tensor([0.6769, 0.6568, 0.8568, 0.7716, 0.8042, 0.7582, 1.0000, 0.8232])
# 1200 ['oval', 'no', 'no', 'yes', 'white', 'yes', 'one', 'yes'] ['round', 'brick', 'right', 'yes', 'white', 'dark', '4', 'yes']
# tensor([0.7800, 0.7431, 0.7843, 1.0000, 1.0000, 0.6684, 0.6856, 1.0000])
# 1208 ['yes', 'no', 'no', 'hand', 'no', 'white', 'no', 'yes'] ['yes', 'batteries', 'no', 'fabric', 'phone', 'white', 'no', 'yes']
# tensor([1.0000, 0.7230, 1.0000, 0.7661, 0.7263, 1.0000, 1.0000, 1.0000])
# 1216 ['curved', 'it', 'bottle', 'yes', 'it', 'yes', 'yes', 'no'] ['rectangular', 'multicolor', 'cup', 'yes', 'multicolor', 'girl', 'hearts', 'love']
# tensor([0.8846, 0.6556, 0.7613, 1.0000, 0.6556, 0.6803, 0.7353, 0.7425])
# 1224 ['vase', 'yes', 'yes', 'blonde', 'rec', 'white', 'yes', 'yes'] ['earrings', 'panda', 'patterned', 'black', 'rectangular', 'beige', 'yes', 'yes']
# tensor([0.8671, 0.7092, 0.7252, 0.7922, 0.7819, 0.7927, 1.0000, 1.0000])
# 1232 ['yes', 'no', 'black', 'white', 'leather', '2', 'normal', 'yes'] ['yes', 'polka-dots', 'black', 'silver', 'leather', '45', 'piano', 'pink']
# tensor([1.0000, 0.6257, 1.0000, 0.8049, 1.0000, 0.6401, 0.6670, 0.6968])
# 1240 ['yes', 'wood', 'yes', 'yes', '6', 'curved', 'gold', '2'] ['yes', 'wood', 'floral', 'pink', '7', 'rounded', 'gold', '2']
# tensor([1.0000, 1.0000, 0.6957, 0.6968, 0.8588, 0.9032, 1.0000, 1.0000])
# 1248 ['necklace', '4', 'yes', 'forward', 'curved', 'no', 'metal', 'yes'] ['beads', '2', 'fleece', 'diagonal', 'rectangular', 'brown', 'gold', 'love']
# tensor([0.8971, 0.7995, 0.6061, 0.7825, 0.8846, 0.7460, 0.8080, 0.7148])
# 1256 ['yes', 'yes', 'lace', 'heels', 'two', 'yes', 'metal', '2'] ['phone', 'bedding', 'eyelets', 'shoes', '2', 'yes', 'camera', '1']
# tensor([0.6663, 0.5854, 0.7492, 0.8956, 0.8447, 1.0000, 0.7250, 0.8405])
# 1264 ['ten', 'yes', 'hat', 'yes', 'yes', 'no', 'yes', '2'] ['slip-on', 'red', 'beanie', 'yes', 'case', 'ring', 'yes', '1']
# tensor([0.6463, 0.7188, 0.6649, 1.0000, 0.6888, 0.7393, 1.0000, 0.8405])
# 1272 ['black', 'trees', '2', 'yes', 'black', 'yes', 'yes', 'yes'] ['black', 'trees', '2', 'orange', 'black', 'yes', 'wholefoods', 'plastic']
# tensor([1.0000, 1.0000, 1.0000, 0.7137, 1.0000, 1.0000, 0.6163, 0.6868])
# 1280 ['two', 'yes', 'yes', 'metal', 'black', 'no', 'yes', 'no'] ['2', 'yes', 'bench', 'logo', 'black', 'yellow', 'yes', 'yes']
# tensor([0.8447, 1.0000, 0.6876, 0.7455, 1.0000, 0.7730, 1.0000, 0.8813])
# 1288 ['no', 'yes', 'yes', 'yes', 'oval', '1', 'white', 'yes'] ['maximum', 'tardis', 'yes', 'yes', 'triangular', '1', 'blue', 'bottles']
# tensor([0.7370, 0.6200, 1.0000, 1.0000, 0.8154, 1.0000, 0.8576, 0.6692])
# 1296 ['yes', 'oval', 'yes', '2', 'yes', 'no', '0', 'yes'] ['yes', 'round', 'yes', '2', 'yes', 'blue', '2', 'yes']
# tensor([1.0000, 0.7800, 1.0000, 1.0000, 1.0000, 0.7789, 0.7515, 1.0000])
# 1304 ['metal', 'legs', 'yes', 'no', 'metal', 'yes', 'no', '2'] ['camera', 'rod', 'yes', 'phone', 'gold', 'cats', 'yes', '1']
# tensor([0.7250, 0.7533, 1.0000, 0.7263, 0.8080, 0.6690, 0.8813, 0.8405])
# 1312 ['yes', '2', 'yes', 'hands', 'metal', 'metal', 'no', 'yes'] ['yes', '1', 'tribal', 'camera', 'metal', 'wheeled', 'chair', 'yes']
# tensor([1.0000, 0.8405, 0.6863, 0.7192, 1.0000, 0.7804, 0.7537, 1.0000])
# 1320 ['1', 'yes', 'metal', 'no', 'blue', 'metal', 'yes', 'it'] ['1', 'denim', 'clear', 'socks', 'grey', 'fabric', 'yes', 'red']
# tensor([1.0000, 0.6660, 0.7112, 0.7266, 0.8508, 0.8091, 1.0000, 0.7608])
# 1328 ['yes', 'no', 'silver', 'black', 'yes', 'metal', 'black', 'no'] ['pink', 'chrome', 'silver', 'black', 'chevron', 'foam', 'purple', 'chair']
# tensor([0.6968, 0.7698, 1.0000, 1.0000, 0.6480, 0.7963, 0.8284, 0.7537])
# 1336 ['yes', '5', 'oval', 'no', 'curved', 'no', 'oval', 'white'] ['red', '2', 'moon', 'duck', 'butterfly', 'no', 'heart', 'black']
# tensor([0.7188, 0.7655, 0.7268, 0.7463, 0.7479, 1.0000, 0.7251, 0.8870])
# 1344 ['hand', 'rec', 'rec', 'no', 'yes', 'white', 'blue', 'no'] ['gauge', 'rectangle', 'heart', 'stars', 'yes', 'white', 'blue', 'handbag']
# tensor([0.7109, 0.8009, 0.7602, 0.7251, 1.0000, 1.0000, 1.0000, 0.7046])
# 1352 ['yes', 'black', 'yes', 'light', 'no', 'black', 'yes', 'blue'] ['brick', 'black', 'yes', 'white', 'grey', 'black', 'yes', 'blue']
# tensor([0.6788, 1.0000, 1.0000, 0.7450, 0.7553, 1.0000, 1.0000, 1.0000])
# 1360 ['wood', '2', 'no', 'curved', 'watch', 'yes', 'curved', 'no'] ['wood', '2', 'yes', 'curved', 'necklace', 'yes', 'rectangular', 'nothing']
# tensor([1.0000, 1.0000, 0.8813, 1.0000, 0.7537, 1.0000, 0.8846, 0.8549])
# 1368 ['yes', 'no', 'maroon', '2', 'metal', '2', 'yes', 'brown'] ['plates', 'sunny', 'red', '2', 'metal', '2', 'yes', 'brown']
# tensor([0.7018, 0.7440, 0.8263, 1.0000, 1.0000, 1.0000, 1.0000, 1.0000])
# 1376 ['no', 'hand', 'yes', 'yes', 'no', 'yes', 'blue', 'no'] ['blue', 'cup', 'no', 'yes', 'vehicle', 'yes', 'blue', 'gold']
# tensor([0.7789, 0.7457, 0.8813, 1.0000, 0.7051, 1.0000, 1.0000, 0.7670])
# 1384 ['yes', 'oval', 'yes', 'no', 'yes', '6', 'yes', 'it'] ['yes', 'circle', 'floral', 'wood', 'case', '2', 'herringbone', 'brown']
# tensor([1.0000, 0.8091, 0.6957, 0.7345, 0.6888, 0.7633, 0.6230, 0.7537])
# 1392 ['it', 'yes', 'no', 'yes', 'yes', 'no', 'oval', 'no'] ['gold', 'yes', 'case', 'yes', 'yellow', 'no', 'circle', 'phone']
# tensor([0.7699, 1.0000, 0.7520, 1.0000, 0.7170, 1.0000, 0.8091, 0.7263])
# 1400 ['mountains', 'yes', 'maroon', 'no', 'hand', 'yes', 'it', 'yes'] ['light', 'panda', 'red', 'case', 'case', 'yes', 'brown', 'foam']
# tensor([0.7094, 0.7092, 0.8263, 0.7520, 0.7814, 1.0000, 0.7537, 0.6838])
# 1408 ['no', 'black', 'no', 'black', 'no', 'no', 'hand', 'left'] ['phone', 'black', 'logo', 'white', 'girl', 'blue', 'planter', 'top']
# tensor([0.7263, 1.0000, 0.7267, 0.8870, 0.7588, 0.7789, 0.7434, 0.7708])
# 1416 ['yes', '2', 'no', 'black', 'white', 'rec', 'short', 'phone'] ['green', '6', 'yellow', 'black', 'black', 'rectangular', 'flat', 'phone']
# tensor([0.6771, 0.7633, 0.7730, 1.0000, 0.8870, 0.7819, 0.7908, 1.0000])
# 1424 ['no', 'ten', 'yes', 'no', 'yes', 'curved', 'yes', 'no'] ['girlboss', 'fifteen', 'quote', 'camo', 'yes', 'cylindrical', 'abstract', 'phone']
# tensor([0.6594, 0.8831, 0.6989, 0.7635, 1.0000, 0.9158, 0.7007, 0.7263])
# 1432 ['no', 'yes', 'sandals', 'yes', '2', '2', 'brown', 'forward'] ['unicorn', 'yes', 'sandal', 'likely', '4', '2', 'brown', 'forward']
# tensor([0.7530, 1.0000, 0.7289, 0.7647, 0.7995, 1.0000, 1.0000, 1.0000])
# 1440 ['yes', 'yes', '2', 'yes', 'oval', 'white', 'yes', 'red'] ['yes', 'black', '1', 'floral', 'oval', 'white', 'yes', 'brown']
# tensor([1.0000, 0.6909, 0.8405, 0.6957, 1.0000, 1.0000, 1.0000, 0.8139])
# 1448 ['white', 'yes', 'blue', 'yes', 'rectangular', 'wood', 'yes', 'black'] ['white', 'butterfly', 'blue', 'yes', 'rectangle', 'wood', 'heart', 'blue']
# tensor([1.0000, 0.6171, 1.0000, 1.0000, 0.8180, 1.0000, 0.7078, 0.8670])
# 1456 ['no', '2', 'no', 'hand', 'yes', 'yes', '2', 'yes'] ['blue', '2', 'yes', 'welt', 'yes', 'camera', '3', 'shoes']
# tensor([0.7789, 1.0000, 0.8813, 0.6691, 1.0000, 0.6218, 0.8246, 0.6678])
# 1464 ['metal', 'yes', 'wood', 'yes', 'oval', 'maroon', 'blue', 'yes'] ['plastic', 'plaid', 'wood', 'yes', 'rounded', 'brown', 'blue', 'girlboss']
# tensor([0.8495, 0.7064, 1.0000, 1.0000, 0.8050, 0.8232, 1.0000, 0.6170])
# 1472 ['yes', 'no', 'yes', 'yes', '2', 'yes', 'no', 'it'] ['yes', 'bamboozled', 'yes', 'ss', '1', 'yes', 'wicker', 'black']
# tensor([1.0000, 0.6992, 1.0000, 0.6998, 0.8405, 1.0000, 0.6540, 0.7439])
# 1480 ['metal', 'yes', '2', 'no', 'white', 'yes', 'no', 'no'] ['metal', 'yes', '2', 'phone', 'brown', 'yes', 'yes', 'yes']
# tensor([1.0000, 1.0000, 1.0000, 0.7263, 0.8407, 1.0000, 0.8813, 0.8813])
# 1488 ['oval', '2', '6', 'yes', 'yes', 'metal', 'rec', 'oval'] ['oval', '1', '4', 'fabric', 'yes', 'gold', 'rectangular', 'round']
# tensor([1.0000, 0.8405, 0.8080, 0.6568, 1.0000, 0.8080, 0.7819, 0.7800])
# 1496 ['yes', 'oval', 'no', 'yes', 'yes', '0', 'no', 'yes'] ['blue', 'round', 'accessory', 'yes', 'yes', 'maize', 'pillow', 'yes']
# tensor([0.7213, 0.7800, 0.7730, 1.0000, 1.0000, 0.6110, 0.7505, 1.0000])
# 1504 ['4', 'forward', 'yes', 'hand', 'left', 'yes', 'yes', 'oval'] ['3', 'horizontal', 'queen', 'handbag', 'front', 'hearts', 'candle', 'round']
# tensor([0.8462, 0.7909, 0.6889, 0.8054, 0.7898, 0.7353, 0.7058, 0.7800])
# 1512 ['2', 'yes', 'yes', 'yes', 'yes', 'yes', 'yes', 'black'] ['many', 'abstract', 'squares', 'partially', 'remote', 'yes', 'yes', 'black']
# tensor([0.7012, 0.7007, 0.7034, 0.7188, 0.6986, 1.0000, 1.0000, 1.0000])
# 1520 ['yes', 'blue', 'blue', '0', '0', 'yes', 'no', 'yes'] ['yes', 'yellow', 'brown', '2', '1', 'case', 'gold', 'flowers']
# tensor([1.0000, 0.8811, 0.8176, 0.7515, 0.8181, 0.6888, 0.7670, 0.6006])
# 1528 ['oval', 'white', 'no', 'phone', 'metal', 'no', 'yes', 'no'] ['round', 'clear', 'screw', 'phone', 'stainless', 'no', 'flowers', 'television']
# tensor([0.7800, 0.8270, 0.7785, 1.0000, 0.7741, 1.0000, 0.6006, 0.6753])
# 1536 ['yes', 'black', 'it', 'phone', 'yes', 'white', 'no', 'yes'] ["daddy's", 'black', 'brown', 'phone', 'yes', 'white', 'no', 'sad']
# tensor([0.7030, 1.0000, 0.7537, 1.0000, 1.0000, 1.0000, 1.0000, 0.6655])
# 1544 ['black', 'feet', 'yes', 'it', 'blue', 'blue', 'oval', 'round'] ['black', 'sole', 'pink', 'gold', 'red', 'blue', 'circular', 'round']
# tensor([1.0000, 0.7948, 0.6968, 0.7699, 0.8734, 1.0000, 0.8544, 1.0000])
# 1552 ['no', 'no', 'it', '0', 'rectangular', 'yes', 'no', 'rec'] ['white', 'denim', 'teal', '2', 'rectangular', 'yes', 'white', 'rectangle']
# tensor([0.7735, 0.7428, 0.7365, 0.7515, 1.0000, 1.0000, 0.7735, 0.8009])
# 1560 ['maroon', 'brown', 'yes', '2', 'no', 'blue', 'no', 'yes'] ['camera', 'cognac', 'terracotta', '1', 'sparkly', 'blue', 'floral', 'gold']
# tensor([0.7040, 0.6196, 0.6065, 0.8405, 0.7185, 1.0000, 0.7728, 0.7181])
# 1568 ['yes', 'yes', 'no', 'one', 'no', 'blue', 'no', 'metal'] ['case', 'case', 'parrot', '1', 'abstract', 'blue', 'case', 'plastic']
# tensor([0.6888, 0.6888, 0.7310, 0.8568, 0.7677, 1.0000, 0.7520, 0.8495])
# 1576 ['yes', 'yes', 'yes', 'rectangular', 'metal', 'yes', 'no', 'it'] ['fabric', 'love', 'circles', 'rectangular', 'bark', 'pink', 'soft', 'multicolor']
# tensor([0.6568, 0.7148, 0.7003, 1.0000, 0.7682, 0.6968, 0.8042, 0.6556])
# 1584 ['yes', 'yes', 'no', 'no', 'white', 'no', 'no', 'leather'] ['whale', 'yes', 'black', 'alone', 'white', 'bird', 'painting', 'woven']
# tensor([0.6168, 1.0000, 0.7441, 0.7514, 1.0000, 0.7024, 0.7380, 0.8549])
# 1592 ['no', 'yes', 'black', 'yes', 'yes', 'no', 'no', 'yes'] ['happy', 'red', 'black', 'blue', 'yes', 'nan', 'autumn', 'gray']
# tensor([0.7653, 0.7188, 1.0000, 0.7213, 1.0000, 0.7800, 0.6837, 0.6992])
# 1600 ['yes', 'rectangular', 'yes', 'long', 'yes', 'blue', 'black', 'yes'] ['motorcycle', 'square', 'yes', 'medium', 'paper', 'blue', 'bronze', 'yes']
# tensor([0.6349, 0.8687, 1.0000, 0.7677, 0.6841, 1.0000, 0.7150, 1.0000])
# 1608 ['0', 'yes', 'yes', 'hands', 'brown', 'yes', 'black', 'yes'] ['6', 'yes', 'yes', 'cup', 'brown', 'yes', 'black', 'folded']
# tensor([0.6888, 1.0000, 1.0000, 0.7356, 1.0000, 1.0000, 1.0000, 0.6961])
# 1616 ['0', 'no', 'man', '2', 'hand', 'no', 'white', 'white'] ['2', 'amazon', 'tie', '2', 'faucet', 'no', 'white', 'gray']
# tensor([0.7515, 0.6946, 0.7238, 1.0000, 0.7180, 1.0000, 1.0000, 0.8108])
# 1624 ['metal', 'oval', 'oval', 'no', 'yes', 'no', 'white', 'yes'] ['silver', 'round', 'cylindrical', 'rectangular', 'yes', 'yes', 'red', 'white']
# tensor([0.8339, 0.7800, 0.8102, 0.7726, 1.0000, 0.8813, 0.8570, 0.6923])
# 1632 ['no', 'yes', 'yes', 'brown', 'no', 'blue', 'no', 'yes'] ['girl', 'yes', 'rug', 'brown', 'orange', 'blue', 'vertical', 'pink']
# tensor([0.7588, 1.0000, 0.6748, 1.0000, 0.7762, 1.0000, 0.7384, 0.6968])
# 1640 ['5', '2', '2', 'no', 'no', 'brown', 'black', 'no'] ['3', '2', '3', 'case', 'amazonbasics', 'beige', 'black', 'yes']
# tensor([0.7833, 1.0000, 0.8246, 0.7520, 0.6630, 0.8152, 1.0000, 0.8813])
# 1648 ['yes', 'motor', 'yes', 'no', 'yes', 'no', 'no', 'tall'] ['yes', 'bike', 'yes', 'hat', 'yes', 'case', 'sequin', 'books']
# tensor([1.0000, 0.8434, 1.0000, 0.7531, 1.0000, 0.7520, 0.7039, 0.6735])
# 1656 ['white', 'no', 'white', 'no', 'yes', 'no', 'black', '2'] ['white', 'display', 'white', 'rack', 'yes', 'no', 'black', '2']
# tensor([1.0000, 0.7317, 1.0000, 0.7586, 1.0000, 1.0000, 1.0000, 1.0000])
# 1664 ['white', '2', 'yes', 'oval', 'rectangular', 'white', 'yes', 'yes'] ['white', '3', 'rose', 'star', 'cube', 'black', 'yes', 'yes']
# tensor([1.0000, 0.8246, 0.6812, 0.7250, 0.8509, 0.8870, 1.0000, 1.0000])
# 1672 ['man', 'yes', 'black', 'white', 'boots', 'oval', 'red', 'oval'] ['shoes', 'yes', 'white', 'white', 'boot', 'circle', 'red', 'round']
# tensor([0.7340, 1.0000, 0.8870, 1.0000, 0.8990, 0.8091, 1.0000, 0.7800])
# 1680 ['yes', 'yes', 'yes', 'no', 'rec', 'yes', 'tan', 'no'] ['yes', 'diamond', 'yes', 'smooth', 'rectangular', 'yes', 'white', 'rose']
# tensor([1.0000, 0.6831, 1.0000, 0.7861, 0.7819, 1.0000, 0.7370, 0.7362])
# 1688 ['white', 'yes', 'no', 'no', 'red', 'rec', 'yes', 'black'] ['white', 'yes', 'rack', 'yes', 'red', 'square', 'cross', 'gray']
# tensor([1.0000, 1.0000, 0.7586, 0.8813, 1.0000, 0.7615, 0.6713, 0.8042])
# 1696 ['yes', 'yes', 'ten', 'oval', 'yes', 'rectangular', 'yes', 'yes'] ['apple', 'pink', 'textured', 'circle', 'shoes', 'rectangle', 'yes', 'yes']
# tensor([0.6424, 0.6968, 0.6362, 0.8091, 0.6678, 0.8180, 1.0000, 1.0000])
# 1704 ['metal', 'no', 'yes', 'hand', '4', 'oval', 'yes', 'yes'] ['metal', 'brown', 'abstract', 'case', '4', 'round', 'yes', 'grey']
# tensor([1.0000, 0.7460, 0.7007, 0.7814, 1.0000, 0.7800, 1.0000, 0.6876])
# 1712 ['no', 'rec', 'no', 'no', 'no', 'green', 'no', 'yes'] ['case', 'heart', 'purple', 'hook', 'plastic', 'green', 'diagonally', 'multicolor']
# tensor([0.7520, 0.7602, 0.7398, 0.7306, 0.7482, 1.0000, 0.6725, 0.6242])
# 1720 ['it', 'light', 'yes', 'yes', 'yes', 'metal', 'yes', 'yes'] ['brown', 'trees', 'yes', 'yes', 'forest', 'leather', 'yes', 'yes']
# tensor([0.7537, 0.7290, 1.0000, 1.0000, 0.6150, 0.8524, 1.0000, 1.0000])
# 1728 ['no', 'black', 'yes', 'no', '2', 'one', '6', 'no'] ['sprinkles', 'yellow', 'yes', 'j', '2', '1', '5', 'boot']
# tensor([0.7267, 0.8540, 1.0000, 0.7330, 1.0000, 0.8568, 0.8520, 0.7672])
# 1736 ['oval', 'yes', 'red', 'yes', 'silver', 'yes', 'yes', 'no'] ['heart', 'partly', 'red', 'yes', 'white', 'pink', 'pockets', 'yes']
# tensor([0.7251, 0.6997, 1.0000, 1.0000, 0.8049, 0.6968, 0.7026, 0.8813])
# 1744 ['green', 'no', '2', 'hand', 'yes', 'rec', 'black', 'yes'] ['green', 'home', '1', '2', 'pink', 'rectangle', 'black', 'writing']
# tensor([1.0000, 0.7398, 0.8405, 0.6790, 0.6968, 0.8009, 1.0000, 0.7033])
# 1752 ['yes', 'trees', 'red', '6', 'vase', 'no', 'yes', 'yes'] ['yes', 'snow', 'red', '5', 'humidifier', 'smooth', 'orange', 'yes']
# tensor([1.0000, 0.7604, 1.0000, 0.8520, 0.7265, 0.7861, 0.7137, 1.0000])
# 1760 ['no', 'moon', 'metal', 'yes', 'white', 'white', 'sky', 'purple'] ['yes', 'moon', 'metal', 'yes', 'white', 'yellow', 'sky', 'purple']
# tensor([0.8813, 1.0000, 1.0000, 1.0000, 1.0000, 0.8761, 1.0000, 1.0000])
# 1768 ['2', 'blue', 'white', 'white', 'curved', 'yes', 'no', 'yes'] ['2', 'blue', 'white', 'white', 'square', 'shapes', 'case', 'renewed']
# tensor([1.0000, 1.0000, 1.0000, 1.0000, 0.8066, 0.7173, 0.7520, 0.7195])
# 1776 ['yes', 'black', 'oval', '2', 'metal', '2', 'yes', 'white'] ['cacti', 'black', 'rectangle', '4', 'fabric', '2', 'yes', 'brass']
# tensor([0.5915, 1.0000, 0.7510, 0.7995, 0.8091, 1.0000, 1.0000, 0.7563])
# 1784 ['curved', 'yes', 'yes', 'no', 'yes', 'yes', 'rec', 'black'] ['round', 'grey', 'plastic', 'laces', 'yes', 'yes', 'rectangular', 'black']
# tensor([0.7014, 0.6876, 0.6868, 0.6490, 1.0000, 1.0000, 0.7819, 1.0000])
# 1792 ['white', 'it', 'left', 'ten', '0', 'black', 'yes', 'vase'] ['silver', 'yellow', 'brown', '4', '1', 'black', 'yes', 'cup']
# tensor([0.8049, 0.7399, 0.7547, 0.6875, 0.8181, 1.0000, 1.0000, 0.7739])
# 1800 ['white', '0', 'no', 'no', 'yes', 'yes', '1', 'yes'] ['green', '3', 'case', 'black', 'woven', 'yes', '1', 'cat']
# tensor([0.8257, 0.6962, 0.7520, 0.7441, 0.7078, 1.0000, 1.0000, 0.7022])
# 1808 ['no', '2', '6', 'no', 'no', 'no', 'yes', 'maroon'] ['yes', '2', '4', 'clear', 'yes', 'fabric', 'heron', 'pink']
# tensor([0.8813, 1.0000, 0.8080, 0.7931, 0.8813, 0.7331, 0.6283, 0.8115])
# 1816 ['yes', 'yes', 'tan', 'yes', 'blue', 'no', 'yes', 'it'] ['blue', 'yes', 'beige', 'yes', 'blue', 'yes', 'red', 'yellow']
# tensor([0.7213, 1.0000, 0.7738, 1.0000, 1.0000, 0.8813, 0.7188, 0.7399])
# 1824 ['black', 'blue', '2', 'rectangular', '2', 'no', 'no', 'yes'] ['black', 'blue', '1', 'rectangle', '2', 'plastic', 'stone', 'yes']
# tensor([1.0000, 1.0000, 0.8405, 0.8180, 1.0000, 0.7482, 0.7622, 1.0000])
# 1832 ['no', 'it', 'no', 'no', 'yes', 'white', 'black', 'yes'] ['eiffel', 'full', 'circle', 'eono', 'yes', 'yellow', 'black', 'parrot']
# tensor([0.6400, 0.7682, 0.7660, 0.7640, 1.0000, 0.8761, 1.0000, 0.6747])
# ...
# tensor([0.7608, 1.0000, 0.7123, 1.0000, 0.8405, 0.7251, 0.6239, 0.7735])
# 4384 ['yes', 'no', 'yes', 'yes', 'rec', 'blue', '0', 'no'] ['bracelet', 'plastic', 'yes', 'yes', 'rectangle', 'blue', '3', 'white']
# tensor([0.6788, 0.7482, 1.0000, 1.0000, 0.8009, 1.0000, 0.6962, 0.7735])
# 4392 ['yes', 'no', 'white', 'yes', 'yes', 'ten', 'oval', '2'] ['yes', 'twelve', 'ivory', 'starter', 'dark', '2', 'round', '3']
# tensor([1.0000, 0.7410, 0.7543, 0.6879, 0.6684, 0.6643, 0.7800, 0.8246])
# 4400 ['black', 'yes', 'yes', '2', 'yes', 'oval', 'blue', 'dog'] ['black', 'pink', 'yes', '4', 'yes', 'floral', 'red', 'dog']
# tensor([1.0000, 0.6968, 1.0000, 0.7995, 1.0000, 0.7916, 0.8734, 1.0000])
# 4408 ['yes', 'oval', 'sliding', 'green', '0', 'no', 'rectangular', 'yes'] ['glitter', 'round', 'laces', 'gold', '3', 'gold', 'square', 'yes']
# tensor([0.6814, 0.7800, 0.6796, 0.7827, 0.6962, 0.7670, 0.8687, 1.0000])
# 4416 ['oval', 'yes', 'yes', 'no', 'leather', '2', 'no', 'no'] ['heart', 'floral', 'sunset', 'white', 'leather', '2', 'electrical', 'pet']
# tensor([0.7251, 0.6957, 0.6742, 0.7735, 1.0000, 1.0000, 0.7371, 0.7550])
# 4424 ['brown', 'yes', 'brown', 'yes', 'no', 'yes', 'no', 'no'] ['brown', 'abstract', 'orange', 'red', 'cup', 'silver', 'no', 'protection']
# tensor([1.0000, 0.7007, 0.8404, 0.7188, 0.7183, 0.6931, 1.0000, 0.7424])
# 4432 ['yes', 'maroon', '0', 'no', 'yes', '2', 'yes', 'yes'] ['queen', 'orange', '5', 'cigarette', 'yes', '1', 'yes', 'yes']
# tensor([0.6889, 0.8193, 0.7043, 0.7388, 1.0000, 0.8405, 1.0000, 1.0000])
# 4440 ['yes', 'it', 'white', 'no', 'yes', 'yes', 'no', 'no'] ['blue', 'orange', 'white', 'vertical', 'no', 'yes', 'chair', 'yes']
# tensor([0.7213, 0.7812, 1.0000, 0.7384, 0.8813, 1.0000, 0.7537, 0.8813])
# 4448 ['yes', 'yes', 'curved', 'yes', 'yes', '6', 'yes', 'black'] ['phone', 'yes', 'stud', 'yes', 'yes', '2', 'yes', 'black']
# tensor([0.6663, 1.0000, 0.8365, 1.0000, 1.0000, 0.7633, 1.0000, 1.0000])
# 4456 ['white', 'no', 'yes', '0', '2', '2', 'yes', 'wood'] ['white', 'flipping', 'yes', '20', '2', '2', 'phone', 'wood']
# tensor([1.0000, 0.7921, 1.0000, 0.6936, 1.0000, 1.0000, 0.6663, 1.0000])
# 4464 ['hands', 'yes', 'yes', 'yes', 'yes', 'yes', 'oval', 'no'] ['flowers', 'yellow', 'yes', 'yes', 'red', 'blue', 'round', 'alone']
# tensor([0.7250, 0.7170, 1.0000, 1.0000, 0.7188, 0.7213, 0.7800, 0.7514])
# 4472 ['yes', 'no', 'no', 'two', 'yes', 'yes', 'yes', 'black'] ['yes', 'case', 'yes', '2', 'pink', 'yes', 'yes', 'black']
# tensor([1.0000, 0.7520, 0.8813, 0.8447, 0.6968, 1.0000, 1.0000, 1.0000])
# 4480 ['5', 'brown', 'no', 'it', 'no', 'yes', 'white', 'no'] ['3', 'brown', 'band', 'brown', 'brown', 'yes', 'pink', 'no']
# tensor([0.7833, 1.0000, 0.7580, 0.7537, 0.7460, 1.0000, 0.8224, 1.0000])
# 4488 ['no', 'rec', 'yes', 'yes', 'no', 'in', 'yes', 'it'] ['yes', 'rectangular', 'multicolor', 'yes', 'cup', 'grass', 'yes', 'black']
# tensor([0.8813, 0.7819, 0.6242, 1.0000, 0.7183, 0.7076, 1.0000, 0.7439])
# 4496 ['black', 'flowers', 'wood', 'yes', 'yes', 'yes', 'black', 'yes'] ['black', 'flowers', 'wood', 'yes', 'yes', 'black', 'red', 'floral']
# tensor([1.0000, 1.0000, 1.0000, 1.0000, 1.0000, 0.6909, 0.8654, 0.6957])
# 4504 ['white', 'yes', '10', 'oval', 'no', 'yes', 'yes', 'metal'] ['black', 'yes', '7', 'oval', 'amazonbasics', 'yes', 'yes', 'silver']
# tensor([0.8870, 1.0000, 0.7527, 1.0000, 0.6630, 1.0000, 1.0000, 0.8339])
# 4512 ['yes', 'yes', 'no', 'yes', 'white', 'yes', 'metal', 'petals'] ['yes', 'skull', 'red', 'yes', 'white', 'pink', 'metal', 'star']
# tensor([1.0000, 0.6461, 0.7723, 1.0000, 1.0000, 0.6968, 1.0000, 0.7329])
# 4520 ['black', 'yes', 'yes', 'black', 'yes', 'no', 'brown', 'yes'] ['gray', 'green', 'blue', 'black', 'yes', 'dual', 'gold', 'blue']
# tensor([0.8042, 0.6771, 0.7213, 1.0000, 1.0000, 0.7954, 0.7775, 0.7213])
# 4528 ['no', 'yes', 'black', 'yes', 'tan', 'maroon', 'yes', 'yes'] ['screws', 'yellow', 'dark', 'yes', 'camel', 'pink', 'yes', 'white']
# tensor([0.6589, 0.7170, 0.8430, 1.0000, 0.7415, 0.8115, 1.0000, 0.6923])
# 4536 ['dress', 'oval', 'no', 'vertical', 'maroon', 'yes', 'red', 'metal'] ['heels', '5', 'case', 'vertical', 'brown', 'yes', 'pink', 'silver']
# tensor([0.7848, 0.6646, 0.7520, 1.0000, 0.8232, 1.0000, 0.8545, 0.8339])
# 4544 ['yes', 'no', 'yes', 'black', 'yes', 'yes', 'red', 'oval'] ['yes', 'snakeskin', 'multicolor', 'black', 'yes', 'yes', 'red', 'sphere']
# tensor([1.0000, 0.6715, 0.6242, 1.0000, 1.0000, 1.0000, 1.0000, 0.7959])
# 4552 ['no', 'no', 'yes', 'blue', 'yes', 'no', 'metal', 'yes'] ['black', 'yes', 'yes', 'blue', 'abstract', 'shoes', 'metal', 'no']
# tensor([0.7441, 0.8813, 1.0000, 1.0000, 0.7007, 0.7220, 1.0000, 0.8813])
# 4560 ['2', '0', 'no', 'yes', 'white', 'no', 'rec', 'black'] ['2', '3', 'red', 'others', 'beige', 'leather', 'square', 'black']
# tensor([1.0000, 0.6962, 0.7723, 0.7295, 0.7927, 0.7513, 0.7615, 1.0000])
# 4568 ['silver', 'yes', 'no', '6', 'yes', '0', 'hand', '10'] ['silver', 'checkered', 'yes', '4', 'shoe', '1', 'headboard', '10:11']
# tensor([1.0000, 0.6479, 0.8813, 0.8080, 0.6752, 0.8181, 0.7279, 0.7297])
# 4576 ['no', 'ten', 'yes', 'yes', 'no', 'yes', 'black', 'white'] ['yes', 'several', 'yellow', 'no', 'no', 'kitty', 'navy', 'chrome']
# tensor([0.8813, 0.8108, 0.7170, 0.8813, 1.0000, 0.7002, 0.6680, 0.7970])
# 4584 ['beige', 'yes', 'no', 'no', 'leather', 'no', 'flip', 'no'] ['neutral', 'yes', 'yes', 'no', 'string', 'brick', 'buckle', 'geometric']
# tensor([0.8412, 1.0000, 0.8813, 1.0000, 0.8235, 0.7431, 0.8493, 0.7519])
# 4592 ['2', 'black', 'no', 'yes', 'it', 'oval', 'no', 'yes'] ['3', 'black', 'case', 'bed', 'brown', 'heart', 'case', 'yes']
# tensor([0.8246, 1.0000, 0.7520, 0.7021, 0.7537, 0.7251, 0.7520, 1.0000])
# 4600 ['one', 'hand', 'yes', 'it', 'yes', 'curved', 'no', 'silver'] ['1', 'cellular', 'yes', 'multi', 'pink', 'curved', 'case', 'silver']
# tensor([0.8568, 0.7859, 1.0000, 0.7922, 0.6968, 1.0000, 0.7520, 1.0000])
# 4608 ['no', 'yes', 'curved', 'yes', 'rectangular', 'black', '0', 'ten'] ['yes', 'yes', 'stiletto', 'rectangular', 'cubes', 'blue', '2', 'multiple']
# tensor([0.8813, 1.0000, 0.7042, 0.6938, 0.7302, 0.8670, 0.7515, 0.7680])
# 4616 ['yes', 'yes', 'yes', 'oval', 'grass', 'yes', 'dark', 'yes'] ['boy', 'green', 'heart', 'rectangle', 'grass', 'orange', 'dark', 'yes']
# tensor([0.7038, 0.6771, 0.7078, 0.7510, 1.0000, 0.7137, 1.0000, 1.0000])
# 4624 ['yes', 'yes', 'no', 'black', '0', 'sandals', 'no', 'no'] ['unicorn', 'phone', 'pink', 'black', '2', 'shoes', 'gray', 'yes']
# tensor([0.6947, 0.6663, 0.7590, 1.0000, 0.7515, 0.8902, 0.7573, 0.8813])
# 4632 ['black', 'no', 'yes', 'pink', 'leather', 'yes', 'rec', 'it'] ['brown', 'matriana', 'pink', 'pink', 'suede', 'floral', 'rectangle', 'grey']
# tensor([0.8273, 0.7012, 0.6968, 1.0000, 0.7538, 0.6957, 0.8009, 0.7529])
# 4640 ['no', 'no', 'on', 'red', 'oval', 'no', 'no', 'yes'] ['skull', 'case', 'top', 'red', 'round', 'no', 'canvas', 'yes']
# tensor([0.6972, 0.7520, 0.7625, 1.0000, 0.7800, 1.0000, 0.7272, 1.0000])
# 4648 ['yes', 'it', 'yes', 'yes', 'yes', '2', 'yes', 'no'] ['brass', 'pink', 'yes', 'yes', 'yes', '2', 'painted', 'portrait']
# tensor([0.6559, 0.7610, 1.0000, 1.0000, 1.0000, 1.0000, 0.6764, 0.6977])
# 4656 ['hat', 'wood', 'brown', 'no', 'ten', 'yes', 'yes', 'no'] ['hat', 'wood', 'brown', 'yes', '4', 'yes', 'yes', 'cellular']
# tensor([1.0000, 1.0000, 1.0000, 0.8813, 0.6875, 1.0000, 1.0000, 0.7597])
# 4664 ['oval', 'woman', '10', 'black', 'yes', 'yes', 'no', 'ten'] ['heart', 'bow', '4', 'black', 'yes', 'lobster', 'no', '365']
# tensor([0.7251, 0.7416, 0.7463, 1.0000, 1.0000, 0.6710, 1.0000, 0.7050])
# 4672 ['black', 'rec', 'yes', 'yes', '2', 'yes', 'black', '2'] ['black', 'rectangular', 'yes', 'yes', '1', 'no', 'black', '2']
# tensor([1.0000, 0.7819, 1.0000, 1.0000, 0.8405, 0.8813, 1.0000, 1.0000])
# 4680 ['metal', 'red', 'hand', 'yes', 'no', 'blue', 'rec', 'maroon'] ['metal', 'black', 'rectangular', 'yes', 'polka', 'blue', 'rectangular', 'brown']
# tensor([1.0000, 0.8654, 0.7802, 1.0000, 0.7227, 1.0000, 0.7819, 0.8232])
# 4688 ['no', 'yes', 'yes', '2', 'hands', 'white', 'no', 'no'] ['case', 'apple', 'yes', '2', 'ring', 'white', 'orange', 'red']
# tensor([0.7520, 0.6424, 1.0000, 1.0000, 0.7488, 1.0000, 0.7762, 0.7723])
# 4696 ['no', '2', 'yes', 'it', 'yes', 'blue', 'brown', 'yes'] ['quilted', '1', 'meow', 'gold', 'anime', 'teal', 'brown', 'butterflies']
# tensor([0.7175, 0.8405, 0.6166, 0.7699, 0.6352, 0.7271, 1.0000, 0.6117])
# 4704 ['no', 'no', 'yes', 'yes', 'black', 'no', 'rectangular', 'no'] ['no', 'socks', 'phone', 'yes', 'blue', 'palm', 'square', 'yes']
# tensor([1.0000, 0.7266, 0.6663, 1.0000, 0.8670, 0.7771, 0.8687, 0.8813])
# 4712 ['long', 'yes', 'metal', 'yes', 'rectangular', 'white', '2', '2'] ['thin', 'yes', 'metal', 'girl', 'rectangular', 'white', '2', '2']
# tensor([0.8306, 1.0000, 1.0000, 0.6803, 1.0000, 1.0000, 1.0000, 1.0000])
# 4720 ['hand', 'no', 'sandals', 'yes', 'yes', 'oval', 'hands', '5'] ['handbag', 'pug', 'sandals', 'case', 'leopard', 'love', 'butterflies', '4']
# tensor([0.8054, 0.6903, 1.0000, 0.6888, 0.6415, 0.6718, 0.7610, 0.8462])
# 4728 ['yes', '0', 'yes', 'black', '2', 'it', 'white', 'no'] ['yes', 'twelve', 'case', 'black', '2', 'white', 'black', 'yes']
# tensor([1.0000, 0.6305, 0.6888, 1.0000, 1.0000, 0.7634, 0.8870, 0.8813])
# 4736 ['yes', 'yes', 'yes', 'yes', 'yes', 'no', 'yes', 'yes'] ['d', 'hearts', 'yes', 'yes', 'yes', 'vertical', 'yes', 'blue']
# tensor([0.6804, 0.7353, 1.0000, 1.0000, 1.0000, 0.7384, 1.0000, 0.7213])
# 4744 ['yes', 'yes', '0', 'vase', 'white', 'white', 'white', 'no'] ['yes', 'yes', '1', 'plant', 'white', 'gold', 'gold', 'white']
# tensor([1.0000, 1.0000, 0.8181, 0.7459, 1.0000, 0.8153, 0.8153, 0.7735])
# 4752 ['metal', 'curved', 'oval', '0', 'hand', 'no', 'it', 'no'] ['plastic', 'pointed', 'hoop', '3', 'phone', 'blue', 'brown', 'rounded']
# tensor([0.8495, 0.9010, 0.7851, 0.6962, 0.7912, 0.7789, 0.7537, 0.7576])
# 4760 ['purple', 'leather', 'yes', 'no', 'left', 'red', 'one', 'oval'] ['purple', 'patent', 'iamme', 'navy', 'up', 'red', '1', 'cylindrical']
# tensor([1.0000, 0.7510, 0.6690, 0.6809, 0.7689, 1.0000, 0.8568, 0.8102])
# 4768 ['ten', 'yes', 'yes', 'yes', 'yes', 'no', 'no', 'yes'] ['twelve', 'eiffel', 'carpet', 'wire', 'yes', 'leather', 'case', 'z']
# tensor([0.8948, 0.5990, 0.6856, 0.7003, 1.0000, 0.7513, 0.7520, 0.6862])
# 4776 ['oval', 'red', 'wood', 'rectangular', 'yes', 'metal', 'yes', 'no'] ['hexagonal', 'red', 'wood', 'rectangular', 'black', 'metal', 'round', 'grainy']
# tensor([0.7329, 1.0000, 1.0000, 1.0000, 0.6909, 1.0000, 0.6175, 0.6590])
# 4784 ['no', 'oval', '0', 'no', 'no', '2', 'yes', 'yes'] ['cartoon', 'round', '3', 'pink', 'yes', '2', 'yes', 'no']
# tensor([0.7480, 0.7800, 0.6962, 0.7590, 0.8813, 1.0000, 1.0000, 0.8813])
# 4792 ['blue', 'black', 'hand', 'handles', 'no', 'yes', 'no', 'it'] ['blue', 'black', 'bucket', 'zippers', 'shoes', 'yes', 'phone', 'beige']
# tensor([1.0000, 1.0000, 0.8036, 0.7634, 0.7220, 1.0000, 0.7263, 0.7914])
# 4800 ['brown', 'no', '2', 'white', 'man', 'no', 'black', 'yes'] ['brown', 'rectangular', '2', 'white', 'shoes', 'modern', 'silver', 'no']
# tensor([1.0000, 0.7726, 1.0000, 1.0000, 0.7340, 0.7512, 0.7803, 0.8813])
# 4808 ['oval', 'yes', 'red', 'black', 'no', 'curved', 'no', 'yes'] ['circle', 'no', 'red', 'black', 'airplane', 'block', 'red', 'teddy']
# tensor([0.8091, 0.8813, 1.0000, 1.0000, 0.7515, 0.7151, 0.7723, 0.6750])
# 4816 ['no', 'black', 'yes', 'no', 'yes', 'yes', 'mountains', 'no'] ['green', 'silver', 'yes', 'plastic', 'yes', 'yes', 'mountains', 'grass']
# tensor([0.7623, 0.7803, 1.0000, 0.7482, 1.0000, 1.0000, 1.0000, 0.7297])
# 4824 ['black', 'yes', 'hands', 'blue', 'blue', 'yes', 'yes', 'yes'] ['silver', 'yes', 'hands', 'blue', 'blue', 'butterfly', 'pink', 'yes']
# tensor([0.7803, 1.0000, 1.0000, 1.0000, 1.0000, 0.6171, 0.6968, 1.0000])
# 4832 ['white', 'oval', 'no', 'yes', 'no', 'no', '10', 'metal'] ['white', 'rectangular', 'no', 'yes', 'no', 'yes', '5', 'metal']
# tensor([1.0000, 0.8418, 1.0000, 1.0000, 1.0000, 0.8813, 0.7521, 1.0000])
# 4840 ['white', 'oval', 'blue', 'yes', 'no', 'mid', 'no', 'red'] ['white', 'heart', 'blue', 'striped', 'cellular_phone_case', 'modern', 'marble', 'red']
# tensor([1.0000, 0.7251, 1.0000, 0.7120, 0.6855, 0.7694, 0.7333, 1.0000])
# 4848 ['yes', 'yes', 'no', 'no', 'white', 'no', 'brown', 'blue'] ['pink', 'yes', 'headphones', 'yes', 'white', 'yes', 'brown', 'blue']
# tensor([0.6968, 1.0000, 0.6663, 0.8813, 1.0000, 0.8813, 1.0000, 1.0000])
# 4856 ['0', 'no', 'silver', 'it', 'yes', 'black', 'blue', 'yes'] ['2', 'shoes', 'white', 'black', 'no', 'black', 'blue', 'yes']
# tensor([0.7515, 0.7220, 0.8049, 0.7439, 0.8813, 1.0000, 1.0000, 1.0000])
# 4864 ['no', 'black', 'yes', '6', 'hand', 'mountains', 'yes', 'yes'] ['no', 'black', 'yes', '4', 'ring', 'mountains', 'yes', 'metallic']
# tensor([1.0000, 1.0000, 1.0000, 0.8080, 0.7768, 1.0000, 1.0000, 0.6771])
# 4872 ['ten', 'yes', '10', 'white', '0', 'no', 'blue', 'hands'] ['many', 'pens', '4', 'white', '3', 'script', 'blue', 'white']
# tensor([0.7845, 0.6988, 0.7463, 1.0000, 0.6962, 0.7258, 1.0000, 0.7583])
# 4880 ['yes', 'oval', 'yes', 'yes', 'yes', 'one', 'no', 'no'] ['couch', 'curved', 'yes', 'rose', 'pineapple', '2', 'case', 'yellow']
# tensor([0.6963, 0.8041, 1.0000, 0.6812, 0.5626, 0.7165, 0.7520, 0.7730])
# 4888 ['no', 'it', 'no', 'yes', 'no', 'it', 'yes', 'no'] ['case', 'black', 'yes', 'yes', 'orange', 'snow', 'round', 'red']
# tensor([0.7520, 0.7439, 0.8813, 1.0000, 0.7762, 0.7162, 0.6175, 0.7723])
# 4896 ['no', 'black', 'black', 'yes', 'wood', 'handles', 'no', 'yes'] ['love', 'black', 'gray', 'yes', 'wood', 'tubes', 'yes', 'blue']
# tensor([0.7425, 1.0000, 0.8042, 1.0000, 1.0000, 0.8671, 0.8813, 0.7213])
# 4904 ['white', 'no', 'no', 'no', 'maroon', 'no', 'yes', 'yes'] ['black', 'trees', 'no', 'yes', 'purple', 'eono', 'yes', 'yes']
# tensor([0.8870, 0.7072, 1.0000, 0.8813, 0.8482, 0.7640, 1.0000, 1.0000])
# 4912 ['hand', 'it', 'two', 'yes', 'no', 'black', 'yes', 'no'] ['abstract', 'pink', 'screws', 'yes', 'logo', 'black', 'cat', 'no']
# tensor([0.7948, 0.7610, 0.6528, 1.0000, 0.7267, 1.0000, 0.7022, 1.0000])
# 4920 ['rec', 'yes', 'oval', 'yes', 'yes', 'yes', '4', 'yes'] ['chevron', 'swirls', 'curved', 'yes', 'fabric', 'rope', '4', 'yes']
# tensor([0.6992, 0.6679, 0.8041, 1.0000, 0.6568, 0.6709, 1.0000, 1.0000])
# 4928 ['black', 'blue', 'metal', 'yes', 'no', 'silver', '2', 'metal'] ['black', 'blue', 'plastic', 'yes', 'no', 'silver', '1', 'plastic']
# tensor([1.0000, 1.0000, 0.8495, 1.0000, 1.0000, 1.0000, 0.8405, 0.8495])
# 4936 ['yes', 'yes', 'yes', 'yes', 'no', 'yes', 'yes', 'yes'] ['yes', 'yes', 'yes', 'tiles', 'wearing', 'yes', 'heron', 'prunes']
# tensor([1.0000, 1.0000, 1.0000, 0.6934, 0.7564, 1.0000, 0.6283, 0.6539])
# 4944 ['green', 'yes', 'yes', 'yes', 'yes', 'blue', 'hand', 'hand'] ['green', 'yes', 'cli-8', 'iamme', 'pink', 'multicolor', 'books', '4']
# tensor([1.0000, 1.0000, 0.5985, 0.6690, 0.6968, 0.7295, 0.7164, 0.6564])
# 4952 ['curved', 'yes', 'no', '2', 'yes', 'no', 'maroon', 'black'] ['curved', 'clothing', 'yes', '2', 'yes', 'floral', 'red', 'black']
# tensor([1.0000, 0.6574, 0.8813, 1.0000, 1.0000, 0.7728, 0.8263, 1.0000])
# 4960 ['no', '0', 'tall', 'red', '2', '2', 'ten', 'black'] ['boot', '2', 'lamp', 'red', '2', '2', '4', 'navy']
# tensor([0.7672, 0.7515, 0.7359, 1.0000, 1.0000, 1.0000, 0.6875, 0.6680])
# 4968 ['hand', 'yes', 'metal', 'no', 'no', 'white', 'no', '6'] ['white', 'yes', 'diamond', 'case', 'flowers', 'white', 'yes', '3']
# tensor([0.7804, 1.0000, 0.8291, 0.7520, 0.6652, 1.0000, 0.8813, 0.7505])
# 4976 ['yes', '6', 'no', 'metal', 'yes', 'yes', 'vase', 'red'] ['red', '5', 'prince', 'plastic', 'yes', 'yes', 'basket', 'blue']
# tensor([0.7188, 0.8520, 0.7558, 0.8495, 1.0000, 1.0000, 0.8067, 0.8734])
# 4984 ['blue', 'brown', 'yes', 'yes', 'it', 'no', 'rec', '2'] ['blue', 'brown', 'yes', 'yes', 'gold', 'cellular', 'rectangle', '2']
# tensor([1.0000, 1.0000, 1.0000, 1.0000, 0.7699, 0.7597, 0.8009, 1.0000])
# 4992 ['rec', 'no', 'yes', 'no', 'yes', 'black', 'yes', 'yes'] ['rectangle', 'canvas', 'suede', 'multicolor', 'yes', 'black', 'green', 'case']
# tensor([0.8009, 0.7272, 0.6242, 0.6759, 1.0000, 1.0000, 0.6771, 0.6888])

# %% [markdown]
# **Evaluation Metrics**

# %% [markdown]
# **String Match and F1**

# %%
acc = accuracy_score(refs, preds) #String Match
f1  = f1_score(refs, preds, average="macro")

print(f"Baseline Evaluation Results on {len(test_df)} examples:")
print(f"  • Accuracy: {acc * 100:.2f}%")
print(f"  • Macro F1  : {f1  * 100:.2f}%")
# Out:
# Baseline Evaluation Results on 5000 examples:
#   • Accuracy: 33.64%
#   • Macro F1  : 3.05%

# %% [markdown]
# **BERT Score and WUPS**

# %%
P, R, F1 = bert_score(preds, refs, lang='en', rescale_with_baseline=True, device=DEVICE) #89
print(P.mean(), R.mean(), F1.mean())
# Take the mean over all examples
avg_precision = P.mean().item()
avg_recall    = R.mean().item()
avg_f1        = F1.mean().item()

print(f"  • BERTScore Precision: {avg_precision*100:.2f}%")
print(f"  • BERTScore Recall   : {avg_recall*100:.2f}%")
print(f"  • BERTScore F1       : {avg_f1*100:.2f}%")

wup_score = calculate_wup_score(preds, refs)
print(f"WUP Score: {wup_score*100:.2f}%")
# Out:
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/482 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/1.42G [00:00<?, ?B/s]
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# tensor(0.9171) tensor(0.8845) tensor(0.8992)
#   • BERTScore Precision: 91.71%
#   • BERTScore Recall   : 88.45%
#   • BERTScore F1       : 89.92%
# WUP Score: 59.67%

# %% [markdown]
# **Save detailed results**

# %%
OUTPUT_CSV = "results_subset.csv"

results_df = pd.DataFrame({
    "path"      : test_df["path"],
    "question"  : test_df["question"],
    "answer"    : refs,
    "prediction": preds
})

results_df.to_csv(OUTPUT_CSV, index=False)
print(f"\nSaved detailed results to {OUTPUT_CSV}")
# Out:
# Saved detailed results to results_subset.csv
