# %%
# !pip install --upgrade google-genai
# !pip install google-generativeai pillow

# %%
import os
import json
from pathlib import Path
import pandas as pd
from PIL import Image
import google.generativeai as genai
import re
import time

# %%
# Set the Gemini API key as an environment variable
os.environ['GEMINI_API_KEY'] = 'AIzaSyDuZrIbeTto6yGuHxreBSMheCLjI9MIfvc'
genai.configure(api_key=os.environ["GEMINI_API_KEY"])

model = genai.GenerativeModel(model_name="gemini-2.0-flash")

# %%
meta_list = []
with open("/kaggle/input/vrproject2/abo-listings/listings/metadata/listings_0.json", "r") as f:
    for line in f:
        obj = json.loads(line)
        meta_list.append(obj)

print(len(meta_list))
# Out:
# 9232

# %%
images_df = pd.read_csv("/kaggle/input/vrproject2/abo-images-small/images/metadata/images.csv")
path_by_id = dict(zip(images_df["image_id"], images_df["path"]))

# %%
records    = []
skip_count = 1235

try:
    for item in meta_list[skip_count:]:
        if not item.get("main_image_id"):
            print("No main image for:", item.get("item_id"))
            continue

        img_id   = item["main_image_id"]
        rel_path = path_by_id.get(img_id)
        if not rel_path:
            continue

        meta_str = json.dumps(item)
        prompt   = (
            "You are creating a Visual Question Answering (VQA) dataset.\n"
            f"Product metadata:\n{meta_str}\n\n"
            "Given this metadata + image, generate 5 distinct question-answer pairs, ensure you know the answer to the question.\n"
            "- Each answer must be exactly one word.\n"
            "- Return a JSON array of {question,answer} objects."
        )

        img      = Image.open(f"/kaggle/input/vrproject2/abo-images-small/images/small/{rel_path}")
        response = model.generate_content([prompt, img])
        raw      = response.text

        # Strip fences
        raw = re.sub(r"^```json\s*\n?", "", raw)
        raw = re.sub(r"\n?```$", "", raw)

        vqa_items = json.loads(raw)
        print("Response for", img_id, ":", vqa_items)

        for qa in vqa_items:
            records.append({
                "image_id": img_id,
                "question": qa["question"],
                "answer":   qa["answer"],
                "path":     rel_path
            })
        print("Last record:", records[-1])

        time.sleep(3)

except Exception as e:
    # Save whatever we have so far
    print(f"Exception encountered: {e!r}")
    df_partial = pd.DataFrame(records)
    df_partial.to_csv("vqa_dataset.csv", index=False)
    print(f"Saved partial results ({len(df_partial)} rows) to vqa_dataset_partial.csv")
# Out:
# Response for 81gsL6HoIrL : [{'question': 'What material is the phone case made of?', 'answer': 'Silicone'}, {'question': "What is the item's color?", 'answer': 'Multicolor'}, {'question': 'What brand is the phone case?', 'answer': 'Solimo'}, {'question': 'What phone model is this case for?', 'answer': 'Motorola'}, {'question': "What is the case's design?", 'answer': 'Wooden'}]
# Last record: {'image_id': '81gsL6HoIrL', 'question': "What is the case's design?", 'answer': 'Wooden', 'path': 'd5/d58c28a4.jpg'}
# Response for 51Yri1SQURL : [{'question': 'What color is the phone case?', 'answer': 'Black'}, {'question': 'What is the brand of the case?', 'answer': 'Solimo'}, {'question': 'Is this a flip cover?', 'answer': 'Yes'}, {'question': 'What is the weight in grams?', 'answer': '50'}, {'question': 'What is the material?', 'answer': 'Plastic'}]
# Last record: {'image_id': '51Yri1SQURL', 'question': 'What is the material?', 'answer': 'Plastic', 'path': '1a/1a20c0d0.jpg'}
# Response for 714Nuj2gyxL : [{'question': 'What is the color of the phone case?', 'answer': 'Transparent'}, {'question': 'What is the brand of this case?', 'answer': 'Solimo'}, {'question': 'What type of product is this?', 'answer': 'Case'}, {'question': 'What phone model is this case for?', 'answer': 'M30'}, {'question': 'Is this case flexible?', 'answer': 'Yes'}]
# Last record: {'image_id': '714Nuj2gyxL', 'question': 'Is this case flexible?', 'answer': 'Yes', 'path': '76/76f42859.jpg'}
# Response for 71yBVoIogKL : [{'question': "What is the case's color?", 'answer': 'Multicolor'}, {'question': 'What is the style of the cover?', 'answer': 'Girlie'}, {'question': 'Is this made of plastic?', 'answer': 'Yes'}, {'question': 'What brand is this?', 'answer': 'Solimo'}, {'question': 'What is the design?', 'answer': 'Flowers'}]
# Last record: {'image_id': '71yBVoIogKL', 'question': 'What is the design?', 'answer': 'Flowers', 'path': '25/25a601db.jpg'}
# Response for 81FLC3ckaCL : [{'question': 'What is the brand of this tea?', 'answer': 'Vedaka'}, {'question': 'What kind of tea is it?', 'answer': 'Darjeeling'}, {'question': 'What is the color of the tea cup?', 'answer': 'White'}, {'question': 'Is this product a grocery?', 'answer': 'Yes'}, {'question': 'What form does this tea come in?', 'answer': 'Leaf'}]
# Last record: {'image_id': '81FLC3ckaCL', 'question': 'What form does this tea come in?', 'answer': 'Leaf', 'path': '86/869ca0ec.jpg'}
# Response for 71iEh47kSQL : [{'question': 'What material is the case made of?', 'answer': 'Hard'}, {'question': 'What is the model for?', 'answer': 'Stylus'}, {'question': 'What is the brand of the case?', 'answer': 'Solimo'}, {'question': 'Is there warranty included?', 'answer': 'No'}, {'question': 'What is the color of the cover?', 'answer': 'Multi-colored'}]
# Last record: {'image_id': '71iEh47kSQL', 'question': 'What is the color of the cover?', 'answer': 'Multi-colored', 'path': 'fa/fadde006.jpg'}
# Response for 61e5l7PTBnL : [{'question': 'What is the heel type?', 'answer': 'Stiletto'}, {'question': 'What is the color of the shoe?', 'answer': 'Pink'}, {'question': 'What type of closure does the shoe have?', 'answer': 'None'}, {'question': "What is the shoe's brand?", 'answer': 'Drop'}, {'question': 'What is the heel height?', 'answer': 'Low'}]
# Last record: {'image_id': '61e5l7PTBnL', 'question': 'What is the heel height?', 'answer': 'Low', 'path': 'f1/f1a1e3c3.jpg'}
# Response for 81uQ4FrxCHL : [{'question': 'What is the color of the phone case?', 'answer': 'Others'}, {'question': 'Is this phone case hard?', 'answer': 'Yes'}, {'question': 'What is the brand?', 'answer': 'Solimo'}, {'question': 'Is the cover 3D?', 'answer': 'Yes'}, {'question': "What is the item's weight in grams?", 'answer': '50'}]
# Last record: {'image_id': '81uQ4FrxCHL', 'question': "What is the item's weight in grams?", 'answer': '50', 'path': 'd4/d4dfe8e6.jpg'}
# Response for 71CXIe06s5L : [{'question': 'What type of case is this?', 'answer': 'Hard'}, {'question': 'What brand is this product?', 'answer': 'Solimo'}, {'question': 'What is the color of the product?', 'answer': 'Multi-colored'}, {'question': 'Is this a mobile cover?', 'answer': 'Yes'}, {'question': 'Is the case 3D printed?', 'answer': 'Yes'}]
# Last record: {'image_id': '71CXIe06s5L', 'question': 'Is the case 3D printed?', 'answer': 'Yes', 'path': 'ca/ca4aeb3e.jpg'}
# Response for 71PlW4WNuwL : [{'question': "What is the case's pattern?", 'answer': 'Pattern'}, {'question': "What is the item's color?", 'answer': 'Multicolor'}, {'question': 'What phone is this for?', 'answer': 'Realme'}, {'question': 'What is the product type?', 'answer': 'Case'}, {'question': 'What is the brand?', 'answer': 'Solimo'}]
# Last record: {'image_id': '71PlW4WNuwL', 'question': 'What is the brand?', 'answer': 'Solimo', 'path': '93/93143995.jpg'}
# Response for 81rtwYmsNGL : [{'question': 'What brand is this?', 'answer': 'Solimo'}, {'question': 'What is the color?', 'answer': 'Others'}, {'question': 'What is the product?', 'answer': 'Case'}, {'question': "What is the item's weight?", 'answer': '50'}, {'question': 'What phone model is this case for?', 'answer': 'Huawei'}]
# Last record: {'image_id': '81rtwYmsNGL', 'question': 'What phone model is this case for?', 'answer': 'Huawei', 'path': '06/06d9a815.jpg'}
# Response for 71GcX2byMOL : [{'question': 'What type of shoes are these?', 'answer': 'Heels'}, {'question': 'What is the color of the shoes?', 'answer': 'Beige'}, {'question': 'What is the brand of these shoes?', 'answer': 'Collective'}, {'question': 'What material is the upper made of?', 'answer': 'Leather'}, {'question': 'What is the model name?', 'answer': 'Mercer'}]
# Last record: {'image_id': '71GcX2byMOL', 'question': 'What is the model name?', 'answer': 'Mercer', 'path': 'f7/f7388174.jpg'}
# Response for 81CyCvye22L : [{'question': "What is the case's primary material?", 'answer': 'Silicon'}, {'question': 'What is the brand name?', 'answer': 'Solimo'}, {'question': 'What is the phone model?', 'answer': 'A25'}, {'question': "What is the case's color?", 'answer': 'Multicolor'}, {'question': 'What type of cover is this?', 'answer': 'Back'}]
# Last record: {'image_id': '81CyCvye22L', 'question': 'What type of cover is this?', 'answer': 'Back', 'path': 'd4/d4ff1346.jpg'}
# Response for 81abl-NkYxL : [{'question': "What is the item's brand?", 'answer': 'Solimo'}, {'question': 'What type of case is this?', 'answer': 'Hard'}, {'question': 'What is the item color?', 'answer': 'Others'}, {'question': 'Is there any warranty?', 'answer': 'No'}, {'question': 'What is the product for?', 'answer': 'Oppo'}]
# Last record: {'image_id': '81abl-NkYxL', 'question': 'What is the product for?', 'answer': 'Oppo', 'path': '0b/0b05a3b7.jpg'}
# Response for 71lm4BrOsGL : [{'question': 'What is the color of the earrings?', 'answer': 'Red'}, {'question': 'What backing do these earrings have?', 'answer': 'Butterfly'}, {'question': 'What is the product type?', 'answer': 'FINEEARRING'}, {'question': 'What stone is in the earrings?', 'answer': 'Garnet'}, {'question': 'What metal are these earrings?', 'answer': 'Silver'}]
# Last record: {'image_id': '71lm4BrOsGL', 'question': 'What metal are these earrings?', 'answer': 'Silver', 'path': 'a2/a2305965.jpg'}
# Response for 81MQj7ZH3XL : [{'question': 'What kind of case is this?', 'answer': 'Hard'}, {'question': 'What is the model of phone?', 'answer': 'M8'}, {'question': 'Is there a warranty?', 'answer': 'No'}, {'question': 'What is the item weight in grams?', 'answer': '50'}, {'question': 'Is the phone case 3D printed?', 'answer': 'Yes'}]
# Last record: {'image_id': '81MQj7ZH3XL', 'question': 'Is the phone case 3D printed?', 'answer': 'Yes', 'path': 'cd/cd662586.jpg'}
# Response for 71U+7zWbSwL : [{'question': "What is the item's color?", 'answer': 'Multi-colored'}, {'question': 'What is the product type?', 'answer': 'CELLULAR_PHONE_CASE'}, {'question': 'What is the case for?', 'answer': 'HTC'}, {'question': 'Is the case hard?', 'answer': 'Yes'}, {'question': 'Is there warranty?', 'answer': 'No'}]
# Last record: {'image_id': '71U+7zWbSwL', 'question': 'Is there warranty?', 'answer': 'No', 'path': '9c/9c7927c0.jpg'}
# Response for 31Zt72dFE9L : [{'question': "What is the set's color?", 'answer': 'Linen'}, {'question': 'What material are these sheets?', 'answer': 'Cotton'}, {'question': 'What is the brand name?', 'answer': 'Pinzon'}, {'question': 'What is the thread count?', 'answer': '1220'}, {'question': 'What is the product type?', 'answer': 'Home'}]
# Last record: {'image_id': '31Zt72dFE9L', 'question': 'What is the product type?', 'answer': 'Home', 'path': 'f7/f77291eb.jpg'}
# Response for 71NEAWJs5GL : [{'question': "What is the case's color?", 'answer': 'Multicolor'}, {'question': 'What phone is this cover for?', 'answer': 'Z4'}, {'question': 'What is the case material?', 'answer': 'Silicon'}, {'question': 'What is the brand?', 'answer': 'Solimo'}, {'question': "What is the case's type?", 'answer': 'Cover'}]
# Last record: {'image_id': '71NEAWJs5GL', 'question': "What is the case's type?", 'answer': 'Cover', 'path': 'fa/fa463d17.jpg'}
# Response for 71gHGtVCmdL : [{'question': 'What is the product color?', 'answer': 'Others'}, {'question': "What is the item's brand?", 'answer': 'Solimo'}, {'question': 'What is printed on the cover?', 'answer': 'Everyone'}, {'question': 'What kind of product is this?', 'answer': 'Case'}, {'question': 'What phone is the case for?', 'answer': 'Motorola'}]
# Last record: {'image_id': '71gHGtVCmdL', 'question': 'What phone is the case for?', 'answer': 'Motorola', 'path': '46/461f57c9.jpg'}
# Response for 81AerTZrOBL : [{'question': 'What brand is this case?', 'answer': 'Solimo'}, {'question': 'What type of product is this?', 'answer': 'Case'}, {'question': 'Is there a warranty?', 'answer': 'No'}, {'question': 'What is the case color?', 'answer': 'Multi-colored'}, {'question': 'What kind of print is on it?', 'answer': '3D'}]
# Last record: {'image_id': '81AerTZrOBL', 'question': 'What kind of print is on it?', 'answer': '3D', 'path': 'cf/cfe54ffb.jpg'}
# Response for 819qGJsBGdL : [{'question': 'What is the stone color?', 'answer': 'Sapphire'}, {'question': 'What type of jewelry are these?', 'answer': 'Earrings'}, {'question': 'What metal are the earrings made of?', 'answer': 'Gold'}, {'question': 'What is the earring style?', 'answer': 'Dangle'}, {'question': 'Are these for Women?', 'answer': 'Yes'}]
# Last record: {'image_id': '819qGJsBGdL', 'question': 'Are these for Women?', 'answer': 'Yes', 'path': '5f/5f82ed54.jpg'}
# Response for 818AbpLrjfL : [{'question': 'What is the product type?', 'answer': 'Lamp'}, {'question': 'What color is the lamp?', 'answer': 'Blanco'}, {'question': "What is the lamp's brand?", 'answer': 'Stone'}, {'question': 'What is the height of the lamp?', 'answer': 'Twenty'}, {'question': 'What is the weight of the lamp?', 'answer': 'Three'}]
# Last record: {'image_id': '818AbpLrjfL', 'question': 'What is the weight of the lamp?', 'answer': 'Three', 'path': '99/990d39f3.jpg'}
# Response for 71cbbJ2WOxL : [{'question': 'What is the color?', 'answer': 'Multicolor'}, {'question': 'What is the brand?', 'answer': 'Solimo'}, {'question': 'What is the product?', 'answer': 'Case'}, {'question': 'What is the item weight in grams?', 'answer': '50'}, {'question': 'What type of design is it?', 'answer': 'Designer'}]
# Last record: {'image_id': '71cbbJ2WOxL', 'question': 'What type of design is it?', 'answer': 'Designer', 'path': '48/485c1178.jpg'}
# Response for 61AsDvz44QL : [{'question': 'What color is the phone case?', 'answer': 'Black'}, {'question': 'What is the material?', 'answer': 'Silicon'}, {'question': 'What brand is it?', 'answer': 'Solimo'}, {'question': 'Is this case flexible?', 'answer': 'Yes'}, {'question': 'What type of product is this?', 'answer': 'Case'}]
# Last record: {'image_id': '61AsDvz44QL', 'question': 'What type of product is this?', 'answer': 'Case', 'path': 'e4/e40b763e.jpg'}
# Response for 81GeVq5xNOL : [{'question': 'What is the brand?', 'answer': 'Solimo'}, {'question': 'What is the color?', 'answer': 'Others'}, {'question': 'What is the product?', 'answer': 'Case'}, {'question': 'What type of case is it?', 'answer': 'Hard'}, {'question': 'What is the phone model?', 'answer': 'Zenfone'}]
# Last record: {'image_id': '81GeVq5xNOL', 'question': 'What is the phone model?', 'answer': 'Zenfone', 'path': '4e/4e4e044b.jpg'}
# Response for 71U1DZD8X7L : [{'question': 'What kind of salt is this?', 'answer': 'Sea'}, {'question': 'What is the net weight in ounces?', 'answer': '26.5'}, {'question': 'What company makes this product?', 'answer': '365'}, {'question': 'Is this product kosher?', 'answer': 'Yes'}, {'question': 'What form is the salt?', 'answer': 'Crystals'}]
# Last record: {'image_id': '71U1DZD8X7L', 'question': 'What form is the salt?', 'answer': 'Crystals', 'path': 'f2/f23da636.jpg'}
# Response for 813Rg5gLM6L : [{'question': 'What is the color of the case?', 'answer': 'Others'}, {'question': 'What brand is this?', 'answer': 'Solimo'}, {'question': 'What is the product?', 'answer': 'Case'}, {'question': 'What is the case for?', 'answer': 'Phone'}, {'question': 'What is the cover printed?', 'answer': '3D'}]
# Last record: {'image_id': '813Rg5gLM6L', 'question': 'What is the cover printed?', 'answer': '3D', 'path': '57/57c2cb69.jpg'}
# Response for 81Y73kfXvqL : [{'question': 'What is the item made of?', 'answer': 'Polyester'}, {'question': "What is the product's brand?", 'answer': 'AmazonBasics'}, {'question': "What is the item's design?", 'answer': 'Pineapple'}, {'question': "What is the item's product type?", 'answer': 'HOME_BED_AND_BATH'}, {'question': 'How many pounds does it weight?', 'answer': 'Two'}]
# Last record: {'image_id': '81Y73kfXvqL', 'question': 'How many pounds does it weight?', 'answer': 'Two', 'path': '9b/9b548331.jpg'}
# Response for 91jjT4+KJpL : [{'question': 'What are these?', 'answer': 'Sheets'}, {'question': 'What is the material?', 'answer': 'Microfibra'}, {'question': 'What company are these from?', 'answer': 'Pinzon'}, {'question': 'What is the product type?', 'answer': 'HOME_BED_AND_BATH'}, {'question': 'What are the sheets made of?', 'answer': 'Polyester'}]
# Last record: {'image_id': '91jjT4+KJpL', 'question': 'What are the sheets made of?', 'answer': 'Polyester', 'path': '31/31c4d81b.jpg'}
# Response for 71PLLdkPZzL : [{'question': 'What material is the bench made of?', 'answer': 'Steel'}, {'question': 'What is the product type?', 'answer': 'Bench'}, {'question': 'What style is the bench?', 'answer': 'Park'}, {'question': "What is the bench's length?", 'answer': '49.6'}, {'question': "What is the item's weight?", 'answer': '32'}]
# Last record: {'image_id': '71PLLdkPZzL', 'question': "What is the item's weight?", 'answer': '32', 'path': '39/394e1ef2.jpg'}
# Response for 71UmVfIOHcL : [{'question': 'What is the brand?', 'answer': 'Solimo'}, {'question': 'What is the color?', 'answer': 'Others'}, {'question': 'What type of case is it?', 'answer': 'Hard'}, {'question': 'What is the item?', 'answer': 'Cover'}, {'question': 'What is the model?', 'answer': 'F11'}]
# Last record: {'image_id': '71UmVfIOHcL', 'question': 'What is the model?', 'answer': 'F11', 'path': '2f/2fca5fbe.jpg'}
# Response for 61cgLle2q6L : [{'question': 'What color is the display?', 'answer': 'Green'}, {'question': 'What brand is this?', 'answer': 'Amazonbasics'}, {'question': 'Is it digital?', 'answer': 'Yes'}, {'question': 'What is it used for?', 'answer': 'Radio'}, {'question': 'What color is the clock?', 'answer': 'Black'}]
# Last record: {'image_id': '61cgLle2q6L', 'question': 'What color is the clock?', 'answer': 'Black', 'path': 'b8/b8a3ead4.jpg'}
# Response for 61xZ2JbsLRL : [{'question': "What is the ring's metal color?", 'answer': 'White'}, {'question': 'What is the main stone shape?', 'answer': 'Round'}, {'question': "What is the item's category?", 'answer': 'Ring'}, {'question': 'What cut is the smaller stone?', 'answer': 'Baguette'}, {'question': 'What is the band color?', 'answer': 'White'}]
# Last record: {'image_id': '61xZ2JbsLRL', 'question': 'What is the band color?', 'answer': 'White', 'path': 'a0/a06d2d6e.jpg'}
# Response for 81fqOJsS6WL : [{'question': 'What color are these hangers?', 'answer': 'Black'}, {'question': 'What are the hangers made of?', 'answer': 'Plastic'}, {'question': 'What is the material covering the hangers?', 'answer': 'Velvet'}, {'question': 'How many hangers are in the pack?', 'answer': 'Thirty'}, {'question': 'What is the brand of these hangers?', 'answer': 'AmazonBasics'}]
# Last record: {'image_id': '81fqOJsS6WL', 'question': 'What is the brand of these hangers?', 'answer': 'AmazonBasics', 'path': '74/7463afbc.jpg'}
# Response for 71VpZ3SNiIL : [{'question': 'What animal is printed on the phone case?', 'answer': 'Panda'}, {'question': 'What is the color of the case?', 'answer': 'Pink'}, {'question': 'What kind of product is this?', 'answer': 'Case'}, {'question': 'Is the case hard or soft?', 'answer': 'Hard'}, {'question': 'How is the case printed?', 'answer': '3D'}]
# Last record: {'image_id': '71VpZ3SNiIL', 'question': 'How is the case printed?', 'answer': '3D', 'path': '56/56130436.jpg'}
# Response for 71nDv1m+SWL : [{'question': "What is the sugar's brand?", 'answer': 'HappyBelly'}, {'question': 'What color is the sugar?', 'answer': 'White'}, {'question': 'What kind of sugar is this?', 'answer': 'Cane'}, {'question': 'What form is the sugar in?', 'answer': 'Granulated'}, {'question': "What is the item's weight?", 'answer': 'Two'}]
# Last record: {'image_id': '71nDv1m+SWL', 'question': "What is the item's weight?", 'answer': 'Two', 'path': '87/870968c4.jpg'}
# Response for 81B3ZByP7TL : [{'question': 'What is the brand?', 'answer': 'Solimo'}, {'question': 'What is the phone model?', 'answer': 'iPhone'}, {'question': 'What is the case color?', 'answer': 'Others'}, {'question': 'What is the case style?', 'answer': 'Hard'}, {'question': 'Does the phone have logo?', 'answer': 'Yes'}]
# Last record: {'image_id': '81B3ZByP7TL', 'question': 'Does the phone have logo?', 'answer': 'Yes', 'path': 'bf/bf04fe9b.jpg'}
# Response for 71N2iqyxKLL : [{'question': "What is the case's material?", 'answer': 'Silicon'}, {'question': "What is the phone case's color?", 'answer': 'Multicolor'}, {'question': 'What is the brand?', 'answer': 'Solimo'}, {'question': 'What is the design on the case?', 'answer': 'Water'}, {'question': 'What is the phone model?', 'answer': 'Tecno'}]
# Last record: {'image_id': '71N2iqyxKLL', 'question': 'What is the phone model?', 'answer': 'Tecno', 'path': '2e/2e04e65c.jpg'}
# Response for 71pHU3bxGzL : [{'question': 'What style is this couch?', 'answer': 'Transitional'}, {'question': "What is the sofa's material?", 'answer': 'Polyester'}, {'question': 'What color is the sofa?', 'answer': 'Tan'}, {'question': "What is the sofa's shape?", 'answer': 'Rectangular'}, {'question': 'What brand is this?', 'answer': 'Ravenna'}]
# Last record: {'image_id': '71pHU3bxGzL', 'question': 'What brand is this?', 'answer': 'Ravenna', 'path': '0c/0c7a76ce.jpg'}
# Response for 81vrbQlLXRL : [{'question': 'What is the weight in ounces?', 'answer': 'Five'}, {'question': 'What is the brand?', 'answer': '365'}, {'question': 'What kind of rub is it?', 'answer': 'Steak'}, {'question': "What is the item's domain?", 'answer': 'wholefoodsmarket'}, {'question': 'Is this from the US?', 'answer': 'Yes'}]
# Last record: {'image_id': '81vrbQlLXRL', 'question': 'Is this from the US?', 'answer': 'Yes', 'path': 'b6/b66efa34.jpg'}
# Response for 813IA0V+qxL : [{'question': 'What color are these bulbs?', 'answer': 'Daylight'}, {'question': 'What type of bulb is this?', 'answer': 'LED'}, {'question': 'What is the brand?', 'answer': 'AmazonCommercial'}, {'question': "What is the item's width?", 'answer': '2.37'}, {'question': 'Are these bulbs dimmable?', 'answer': 'Yes'}]
# Last record: {'image_id': '813IA0V+qxL', 'question': 'Are these bulbs dimmable?', 'answer': 'Yes', 'path': '3b/3b548d16.jpg'}
# Response for A1DA+Vyi2DL : [{'question': "What is the case's color?", 'answer': 'Pink'}, {'question': "What is the cover's brand?", 'answer': 'AmazonBasics'}, {'question': 'What material is it?', 'answer': 'Leather'}, {'question': 'What is the product?', 'answer': 'Cover'}, {'question': "What is item's condition?", 'answer': 'New'}]
# Last record: {'image_id': 'A1DA+Vyi2DL', 'question': "What is item's condition?", 'answer': 'New', 'path': '8d/8d0e9bb9.jpg'}
# Response for 71aoNB7iBlL : [{'question': 'What is the color of the case?', 'answer': 'Multicolor'}, {'question': 'What is the brand?', 'answer': 'Solimo'}, {'question': 'What type of case is it?', 'answer': 'Back'}, {'question': 'What phone is this for?', 'answer': 'Samsung'}, {'question': 'Is there any warranty?', 'answer': 'No'}]
# Last record: {'image_id': '71aoNB7iBlL', 'question': 'Is there any warranty?', 'answer': 'No', 'path': '75/750cac83.jpg'}
# Response for 715LMwwxF7L : [{'question': 'What color is the table?', 'answer': 'Black'}, {'question': "What is the table's brand?", 'answer': 'Ravenna'}, {'question': 'What material is the table?', 'answer': 'Wood'}, {'question': "What is the table's width?", 'answer': '42'}, {'question': 'Does the table have drawer?', 'answer': 'Yes'}]
# Last record: {'image_id': '715LMwwxF7L', 'question': 'Does the table have drawer?', 'answer': 'Yes', 'path': 'ed/ede074b0.jpg'}
# Response for 81MlYbF+PwL : [{'question': 'What brand is this?', 'answer': 'Solimo'}, {'question': "What's the product type?", 'answer': 'SKIN_MOISTURIZER'}, {'question': 'What kind of relief?', 'answer': 'Sunburn'}, {'question': 'What size is it?', 'answer': 'Eight'}, {'question': 'Is menthol contained?', 'answer': 'Yes'}]
# Last record: {'image_id': '81MlYbF+PwL', 'question': 'Is menthol contained?', 'answer': 'Yes', 'path': '2f/2f326911.jpg'}
# Response for 81KovnIinzL : [{'question': "What is the case's brand?", 'answer': 'Solimo'}, {'question': "What is the case's material?", 'answer': 'Silicon'}, {'question': 'What is the color of the case?', 'answer': 'Multicolor'}, {'question': 'What phone is this case for?', 'answer': 'Nokia'}, {'question': 'What type of product is this?', 'answer': 'Case'}]
# Last record: {'image_id': '81KovnIinzL', 'question': 'What type of product is this?', 'answer': 'Case', 'path': 'bd/bd639d0c.jpg'}
# Response for 710JbDnUopL : [{'question': 'What is the product type?', 'answer': 'CELLULAR_PHONE_CASE'}, {'question': 'What is the color?', 'answer': 'Others'}, {'question': 'What is the brand?', 'answer': 'Solimo'}, {'question': "What is the case's material?", 'answer': 'Hard'}, {'question': 'What type of printing is used?', 'answer': '3D'}]
# Last record: {'image_id': '710JbDnUopL', 'question': 'What type of printing is used?', 'answer': '3D', 'path': 'b0/b020218b.jpg'}
# Response for 71h5tAFEjYL : [{'question': "What is the case's material?", 'answer': 'Silicon'}, {'question': "What is the case's color?", 'answer': 'Multicolor'}, {'question': 'Is this a phone case?', 'answer': 'Yes'}, {'question': 'What is the phone model?', 'answer': 'Samsung'}, {'question': 'Is the design stylish?', 'answer': 'Yes'}]
# Last record: {'image_id': '71h5tAFEjYL', 'question': 'Is the design stylish?', 'answer': 'Yes', 'path': '74/74ae2c96.jpg'}
# Response for 91M-8uX3odL : [{'question': 'What is the color of this item?', 'answer': 'Orange'}, {'question': 'What is the product type?', 'answer': 'Suitcase'}, {'question': 'What is the brand of this luggage?', 'answer': 'AmazonBasics'}, {'question': 'How many wheels does this item have?', 'answer': 'Four'}, {'question': "What is the suitcase's height in inches?", 'answer': '26.6'}]
# Last record: {'image_id': '91M-8uX3odL', 'question': "What is the suitcase's height in inches?", 'answer': '26.6', 'path': 'c4/c47dc1ff.jpg'}
# Response for 81SBoTzUT8L : [{'question': 'What is the material of the case?', 'answer': 'Hard'}, {'question': 'What kind of printing is on the case?', 'answer': '3D'}, {'question': 'What is the brand?', 'answer': 'Solimo'}, {'question': 'What is the color of the case?', 'answer': 'Multi-colored'}, {'question': 'What is the product type?', 'answer': 'Case'}]
# Last record: {'image_id': '81SBoTzUT8L', 'question': 'What is the product type?', 'answer': 'Case', 'path': '15/15e7de37.jpg'}
# Response for A1aXd6aSeQL : [{'question': 'What animal is in the image?', 'answer': 'Horses'}, {'question': "What is the art's background?", 'answer': 'Desert'}, {'question': 'What is the medium?', 'answer': 'Canvas'}, {'question': 'Is the sky visible?', 'answer': 'Yes'}, {'question': "What is the art's brand?", 'answer': 'Rivet'}]
# Last record: {'image_id': 'A1aXd6aSeQL', 'question': "What is the art's brand?", 'answer': 'Rivet', 'path': 'ad/adeef29e.jpg'}
# Response for 715Fod91EQL : [{'question': "What is the case's pattern?", 'answer': 'Heart'}, {'question': "What is the cover's brand?", 'answer': 'Solimo'}, {'question': "What is the case's color?", 'answer': 'Multicolor'}, {'question': 'What is the cover material?', 'answer': 'Plastic'}, {'question': 'What phone model is this for?', 'answer': 'M31'}]
# Last record: {'image_id': '715Fod91EQL', 'question': 'What phone model is this for?', 'answer': 'M31', 'path': 'cf/cfd5affb.jpg'}
# Response for 71Rru-CZSvL : [{'question': 'What is the product type?', 'answer': 'Sandal'}, {'question': 'What kind of heel does the sandal have?', 'answer': 'Block'}, {'question': 'What is the brand?', 'answer': 'find.'}, {'question': 'What is the material of the straps?', 'answer': 'Leather'}, {'question': 'What is the style of shoe?', 'answer': 'Pumps'}]
# Last record: {'image_id': '71Rru-CZSvL', 'question': 'What is the style of shoe?', 'answer': 'Pumps', 'path': '9d/9d72c834.jpg'}
# Response for 7100VL2LA9L : [{'question': 'What color is the phone case?', 'answer': 'Clear'}, {'question': 'What phone is the case for?', 'answer': 'A3'}, {'question': 'Is the case flexible?', 'answer': 'Yes'}, {'question': 'What is the material?', 'answer': 'Plastic'}, {'question': 'Is it tear resistant?', 'answer': 'Yes'}]
# Last record: {'image_id': '7100VL2LA9L', 'question': 'Is it tear resistant?', 'answer': 'Yes', 'path': '96/96447057.jpg'}
# Response for 81uw-D87CcL : [{'question': 'What color are the knee pads?', 'answer': 'Brown'}, {'question': 'What is the brand?', 'answer': 'Kneekers'}, {'question': 'Are these knee pads washable?', 'answer': 'Yes'}, {'question': 'What are these designed for?', 'answer': 'Crawling'}, {'question': 'What animal is on the knee pads?', 'answer': 'Monster'}]
# Last record: {'image_id': '81uw-D87CcL', 'question': 'What animal is on the knee pads?', 'answer': 'Monster', 'path': 'b5/b5813543.jpg'}
# Response for 61MeNEqHvzL : [{'question': 'What is the item for?', 'answer': 'Phone'}, {'question': 'What is the color of the phone case?', 'answer': 'Pink'}, {'question': 'What kind of case is this?', 'answer': 'Hard'}, {'question': 'What brand is the case?', 'answer': 'Solimo'}, {'question': 'What type of printing is on the cover?', 'answer': '3D'}]
# Last record: {'image_id': '61MeNEqHvzL', 'question': 'What type of printing is on the cover?', 'answer': '3D', 'path': '40/408d290d.jpg'}
# Response for 61OnkGVhMWL : [{'question': 'What is the brand?', 'answer': 'AmazonBasics'}, {'question': 'What color are the brushes?', 'answer': 'Blue'}, {'question': 'How many sets?', 'answer': 'Six'}, {'question': 'What is the product type?', 'answer': 'PAINT_BRUSH'}, {'question': 'What is the length?', 'answer': 'Eight'}]
# Last record: {'image_id': '61OnkGVhMWL', 'question': 'What is the length?', 'answer': 'Eight', 'path': '35/3595924e.jpg'}
# Response for 71oEKinsSfL : [{'question': 'What color is the product?', 'answer': 'Bianco'}, {'question': 'What is the product type?', 'answer': 'CLOTHES_RACK'}, {'question': 'What is the brand?', 'answer': 'Movian'}, {'question': 'What is the product style?', 'answer': 'Scarpiera'}, {'question': "What is the product's weight?", 'answer': '30'}]
# Last record: {'image_id': '71oEKinsSfL', 'question': "What is the product's weight?", 'answer': '30', 'path': '47/47e8e384.jpg'}
# Response for 71Ko37Op27L : [{'question': "What is the case's brand?", 'answer': 'Solimo'}, {'question': "What is the case's primary color?", 'answer': 'Multicolor'}, {'question': 'What is the case material?', 'answer': 'Silicon'}, {'question': 'What is the design on the case?', 'answer': 'Solar'}, {'question': 'What is the item type?', 'answer': 'Case'}]
# Last record: {'image_id': '71Ko37Op27L', 'question': 'What is the item type?', 'answer': 'Case', 'path': 'ec/ecdeb44f.jpg'}
# Response for 71dUXpDLxWL : [{'question': "What is the pendant's shape?", 'answer': 'Horse'}, {'question': 'What is the necklace color?', 'answer': 'Silver'}, {'question': 'What metal is the necklace?', 'answer': 'Metal'}, {'question': 'What type of clasp?', 'answer': 'Spring-ring'}, {'question': "What is the necklace's brand?", 'answer': 'Amazon'}]
# Last record: {'image_id': '71dUXpDLxWL', 'question': "What is the necklace's brand?", 'answer': 'Amazon', 'path': 'f3/f317c0dc.jpg'}
# Response for 61XyyoiPxtL : [{'question': 'What is the material of the phone case?', 'answer': 'Silicon'}, {'question': "What is the case's color?", 'answer': 'Multicolor'}, {'question': 'What is the brand of this product?', 'answer': 'Solimo'}, {'question': 'What phone is this case for?', 'answer': 'Samsung'}, {'question': 'Is this case for a phone?', 'answer': 'Yes'}]
# Last record: {'image_id': '61XyyoiPxtL', 'question': 'Is this case for a phone?', 'answer': 'Yes', 'path': '2a/2a3dbab6.jpg'}
# Response for 61WZ3s0e7zL : [{'question': 'What is the background color of the phone case?', 'answer': 'Pink'}, {'question': 'What animal is pictured on the case?', 'answer': 'Kitty'}, {'question': 'What is the material of the case?', 'answer': 'Silicone'}, {'question': 'What is the brand of the case?', 'answer': 'Solimo'}, {'question': 'What style is this?', 'answer': 'Comics'}]
# Last record: {'image_id': '61WZ3s0e7zL', 'question': 'What style is this?', 'answer': 'Comics', 'path': 'bd/bd3364d0.jpg'}
# Response for 71ySVDDfCWL : [{'question': 'What is the material of the cover?', 'answer': 'Plastic'}, {'question': 'What is the color of the case?', 'answer': 'Multicolor'}, {'question': 'What brand is this case?', 'answer': 'Solimo'}, {'question': 'What is the pattern on the cover?', 'answer': 'Galaxy'}, {'question': 'What is the product type?', 'answer': 'Case'}]
# Last record: {'image_id': '71ySVDDfCWL', 'question': 'What is the product type?', 'answer': 'Case', 'path': '42/42550998.jpg'}
# Response for 61UY55f-X7L : [{'question': 'What color is the power strip?', 'answer': 'White'}, {'question': 'How many outlets does it have?', 'answer': 'Six'}, {'question': "What's the item's brand?", 'answer': 'AmazonBasics'}, {'question': 'What protects small appliances?', 'answer': 'Surge'}, {'question': 'What kind of cord does the strip have?', 'answer': 'Power'}]
# Last record: {'image_id': '61UY55f-X7L', 'question': 'What kind of cord does the strip have?', 'answer': 'Power', 'path': 'cd/cd327c05.jpg'}
# Response for 61v2ELx2PWL : [{'question': 'What is the product type?', 'answer': 'Case'}, {'question': 'What is the brand?', 'answer': 'Solimo'}, {'question': "What is the item's color?", 'answer': 'Others'}, {'question': 'What is the product for?', 'answer': 'Oppo'}, {'question': 'Is there a warranty?', 'answer': 'No'}]
# Last record: {'image_id': '61v2ELx2PWL', 'question': 'Is there a warranty?', 'answer': 'No', 'path': 'ea/eaa3dc3a.jpg'}
# Response for 71LSUGvB9YL : [{'question': 'What type of jewelry is this?', 'answer': 'Ring'}, {'question': 'What cut is the stone?', 'answer': 'Round'}, {'question': "What is the stone's color?", 'answer': 'Clear'}, {'question': "What is the item's material?", 'answer': 'Silver'}, {'question': "What is the product's brand?", 'answer': 'Amazon'}]
# Last record: {'image_id': '71LSUGvB9YL', 'question': "What is the product's brand?", 'answer': 'Amazon', 'path': '9f/9f7fc866.jpg'}
# Response for 71PgW6P9FkL : [{'question': 'What brand is this case?', 'answer': 'Solimo'}, {'question': 'What type of case is it?', 'answer': 'Hard'}, {'question': 'What is the color?', 'answer': 'Others'}, {'question': 'What is printed on the case?', 'answer': 'Pairs'}, {'question': 'What phone is this case for?', 'answer': 'Lenovo'}]
# Last record: {'image_id': '71PgW6P9FkL', 'question': 'What phone is this case for?', 'answer': 'Lenovo', 'path': '48/482e50a0.jpg'}
# Response for 910vvDJfNcL : [{'question': 'What material is the sofa made of?', 'answer': 'Wood'}, {'question': 'What is the product type?', 'answer': 'Sofa'}, {'question': "What is the sofa's style?", 'answer': 'Transitional'}, {'question': 'What brand is this item?', 'answer': 'Stone'}, {'question': 'What color is the sofa?', 'answer': 'Haze'}]
# Last record: {'image_id': '910vvDJfNcL', 'question': 'What color is the sofa?', 'answer': 'Haze', 'path': '1a/1a22342c.jpg'}
# Response for 81fn0cacaDL : [{'question': 'What kind of capsules are these?', 'answer': 'Liquid'}, {'question': 'What company sells this product?', 'answer': 'Wholefoods'}, {'question': 'What is the count of the capsules?', 'answer': 'Sixty'}, {'question': 'What is the product name?', 'answer': 'Kava'}, {'question': 'Are the capsules vegan?', 'answer': 'Yes'}]
# Last record: {'image_id': '81fn0cacaDL', 'question': 'Are the capsules vegan?', 'answer': 'Yes', 'path': 'b1/b1416bd8.jpg'}
# Response for 51ER764mIvL : [{'question': 'What color is the phone cover?', 'answer': 'Black'}, {'question': 'What type of case is it?', 'answer': 'Flip'}, {'question': 'What is the case material?', 'answer': 'Plastic'}, {'question': 'What brand is it?', 'answer': 'Solimo'}, {'question': 'Does the case have screen protection?', 'answer': 'Yes'}]
# Last record: {'image_id': '51ER764mIvL', 'question': 'Does the case have screen protection?', 'answer': 'Yes', 'path': '68/6878c1f4.jpg'}
# Response for 71RFYHsKgsL : [{'question': 'What is the color of the loafers?', 'answer': 'Black'}, {'question': 'What kind of shoes are these?', 'answer': 'Loafers'}, {'question': 'What is the toe style?', 'answer': 'Round'}, {'question': 'What is the brand name?', 'answer': 'Nubeno'}, {'question': 'What is the material?', 'answer': 'Leather'}]
# Last record: {'image_id': '71RFYHsKgsL', 'question': 'What is the material?', 'answer': 'Leather', 'path': '18/184979a0.jpg'}
# Response for 71-L+jYDaYL : [{'question': 'What is the brand?', 'answer': 'Solimo'}, {'question': 'What type of case is this?', 'answer': 'Hard'}, {'question': 'What is the item made for?', 'answer': 'Phone'}, {'question': 'What is the color?', 'answer': 'Multicolor'}, {'question': 'Is there warranty?', 'answer': 'No'}]
# Last record: {'image_id': '71-L+jYDaYL', 'question': 'Is there warranty?', 'answer': 'No', 'path': 'fd/fd778758.jpg'}
# Response for 71dQoChI--L : [{'question': 'What makeup item is this?', 'answer': 'Eyeshadow'}, {'question': 'What color is the product?', 'answer': 'Purple'}, {'question': 'How many eyeshadows included?', 'answer': 'Three'}, {'question': 'What is the product style?', 'answer': 'Affair'}, {'question': 'What is the product brand?', 'answer': 'Find'}]
# Last record: {'image_id': '71dQoChI--L', 'question': 'What is the product brand?', 'answer': 'Find', 'path': '7a/7a2adb02.jpg'}
# Response for 919ohNZQDnL : [{'question': 'What flavor are the croutons?', 'answer': 'Garlic'}, {'question': 'What is the brand name?', 'answer': '365'}, {'question': 'What kind of product is this?', 'answer': 'Grocery'}, {'question': 'Are the croutons vegetarian?', 'answer': 'Yes'}, {'question': 'What is the weight in pounds?', 'answer': '0.37'}]
# Last record: {'image_id': '919ohNZQDnL', 'question': 'What is the weight in pounds?', 'answer': '0.37', 'path': '38/38e87c2d.jpg'}
# Response for 71HRXZMTaXL : [{'question': 'What color is the oven glove?', 'answer': 'Green'}, {'question': 'What is the main material?', 'answer': 'Cotton'}, {'question': "What is the item's style?", 'answer': 'Paisley'}, {'question': 'What brand is this item?', 'answer': 'Solimo'}, {'question': 'Is the item padded?', 'answer': 'Yes'}]
# Last record: {'image_id': '71HRXZMTaXL', 'question': 'Is the item padded?', 'answer': 'Yes', 'path': 'ed/ed4e3332.jpg'}
# Response for 81juqR3slRL : [{'question': "What is the case's color?", 'answer': 'Multi-colored'}, {'question': 'What is the material of the case?', 'answer': 'Silicon'}, {'question': 'What phone is this case for?', 'answer': 'U20'}, {'question': 'What is the product type?', 'answer': 'Case'}, {'question': 'What is the brand?', 'answer': 'Solimo'}]
# Last record: {'image_id': '81juqR3slRL', 'question': 'What is the brand?', 'answer': 'Solimo', 'path': 'c6/c651db4a.jpg'}
# Response for 81Jw1z1rNLL : [{'question': 'What color are the cat ear hats?', 'answer': 'Pink'}, {'question': 'What type of product is this?', 'answer': 'Accessory'}, {'question': 'What brand is this?', 'answer': 'Spotted'}, {'question': 'What material are these made of?', 'answer': 'Acrylic'}, {'question': 'What pattern is on the one set?', 'answer': 'Rainbow'}]
# Last record: {'image_id': '81Jw1z1rNLL', 'question': 'What pattern is on the one set?', 'answer': 'Rainbow', 'path': '43/43999f7b.jpg'}
# Response for 71iaGVxH0zL : [{'question': 'What is the brand?', 'answer': 'Solimo'}, {'question': 'What kind of case is this?', 'answer': 'Hard'}, {'question': "What is the cover's color?", 'answer': 'Others'}, {'question': "What is the cover's design?", 'answer': 'Golden'}, {'question': 'What is the product type?', 'answer': 'Case'}]
# Last record: {'image_id': '71iaGVxH0zL', 'question': 'What is the product type?', 'answer': 'Case', 'path': 'db/db3d1c17.jpg'}
# Response for 71YaJmwkpIL : [{'question': 'Is there warranty for the cover?', 'answer': 'No'}, {'question': 'What is the color?', 'answer': 'Others'}, {'question': 'What is the brand?', 'answer': 'Solimo'}, {'question': 'What type of case is it?', 'answer': 'Hard'}, {'question': 'What is the phone model?', 'answer': 'Oppo'}]
# Last record: {'image_id': '71YaJmwkpIL', 'question': 'What is the phone model?', 'answer': 'Oppo', 'path': 'ce/cedc2840.jpg'}
# Response for 71R6qRR8bHL : [{'question': 'What kind of oil is this?', 'answer': 'Avocado'}, {'question': 'What is the brand?', 'answer': '365'}, {'question': 'Is this product vegan?', 'answer': 'Yes'}, {'question': 'Is product Kosher?', 'answer': 'Yes'}, {'question': 'Is this GMO-free?', 'answer': 'Yes'}]
# Last record: {'image_id': '71R6qRR8bHL', 'question': 'Is this GMO-free?', 'answer': 'Yes', 'path': '4e/4e775832.jpg'}
# Response for 81YzAfzi8NL : [{'question': 'What is the item weight in grams?', 'answer': '50'}, {'question': 'What kind of design is printed?', 'answer': 'Designer'}, {'question': 'What is the brand of the cover?', 'answer': 'Solimo'}, {'question': 'What type of case is this?', 'answer': 'Hard'}, {'question': "What is the item's color?", 'answer': 'Others'}]
# Last record: {'image_id': '81YzAfzi8NL', 'question': "What is the item's color?", 'answer': 'Others', 'path': '86/86b1efe7.jpg'}
# Response for 81YNWL7P-cL : [{'question': 'What is the color of the cover?', 'answer': 'Multicolor'}, {'question': 'What phone is this cover for?', 'answer': 'Lenovo'}, {'question': 'What type of case is it?', 'answer': 'Hard'}, {'question': 'Is this a bumper case?', 'answer': 'No'}, {'question': 'What is the brand name?', 'answer': 'Solimo'}]
# Last record: {'image_id': '81YNWL7P-cL', 'question': 'What is the brand name?', 'answer': 'Solimo', 'path': '90/90602dd0.jpg'}
# Response for 718LNt1FHuL : [{'question': 'What is the color of the phone case?', 'answer': 'Multicolor'}, {'question': 'What brand is the phone case?', 'answer': 'Solimo'}, {'question': 'Is the case hard or soft?', 'answer': 'Hard'}, {'question': 'What type of print does the cover have?', 'answer': '3D'}, {'question': 'What phone model is this for?', 'answer': 'Vivo'}]
# Last record: {'image_id': '718LNt1FHuL', 'question': 'What phone model is this for?', 'answer': 'Vivo', 'path': 'c5/c53fc171.jpg'}
# Response for 71sS3WFE3VL : [{'question': 'What type of jewelry is this?', 'answer': 'Ring'}, {'question': 'What is the main stone material?', 'answer': 'Zirconia'}, {'question': 'What is the metal material?', 'answer': 'Silver'}, {'question': "What is the item's style?", 'answer': 'Ring'}, {'question': 'How many stones?', 'answer': 'Seven'}]
# Last record: {'image_id': '71sS3WFE3VL', 'question': 'How many stones?', 'answer': 'Seven', 'path': 'c1/c1d25cdb.jpg'}
# Response for 81qw1pkxLxL : [{'question': 'What material is the phone cover made of?', 'answer': 'Silicon'}, {'question': 'What is the color of the cover?', 'answer': 'Multicolor'}, {'question': 'Which brand sells this cover?', 'answer': 'Solimo'}, {'question': 'Is it a back or flip cover?', 'answer': 'Back'}, {'question': 'What is the design?', 'answer': 'Kitty'}]
# Last record: {'image_id': '81qw1pkxLxL', 'question': 'What is the design?', 'answer': 'Kitty', 'path': '0c/0c740dc6.jpg'}
# Response for 81s47cyq6nL : [{'question': 'What is the item weight in pounds?', 'answer': 'Two'}, {'question': 'What kind of mix is this?', 'answer': 'Trail'}, {'question': 'What is the brand name?', 'answer': 'Happy'}, {'question': 'What flavor is this?', 'answer': 'Spicy'}, {'question': 'What company owns the brand?', 'answer': 'Amazon'}]
# Last record: {'image_id': '81s47cyq6nL', 'question': 'What company owns the brand?', 'answer': 'Amazon', 'path': 'd6/d69206ac.jpg'}
# Response for 71gUWLQlrkL : [{'question': 'What brand is this product?', 'answer': 'Solimo'}, {'question': 'What type of case is this?', 'answer': 'Back'}, {'question': 'What material is the case?', 'answer': 'Hard'}, {'question': 'What phone is the case for?', 'answer': 'Vivo'}, {'question': "What is the item's color?", 'answer': 'Others'}]
# Last record: {'image_id': '71gUWLQlrkL', 'question': "What is the item's color?", 'answer': 'Others', 'path': '2b/2b1b36e5.jpg'}
# Response for 81LyZUXjZvL : [{'question': 'What kind of butter is this?', 'answer': 'Peanut'}, {'question': 'What is the brand?', 'answer': '365'}, {'question': 'Is this product organic?', 'answer': 'Yes'}, {'question': "What is the item's weight?", 'answer': 'Pound'}, {'question': 'What kind of spread is this?', 'answer': 'Crunchy'}]
# Last record: {'image_id': '81LyZUXjZvL', 'question': 'What kind of spread is this?', 'answer': 'Crunchy', 'path': '2b/2bcb8844.jpg'}
# Response for 71NWUMBaTKL : [{'question': 'What is the primary color?', 'answer': 'Multicolor'}, {'question': 'What is the pattern on the case?', 'answer': 'Butterfly'}, {'question': 'What is the case material?', 'answer': 'Silicon'}, {'question': 'Is this a cover or case?', 'answer': 'Cover'}, {'question': 'What is the item brand?', 'answer': 'Solimo'}]
# Last record: {'image_id': '71NWUMBaTKL', 'question': 'What is the item brand?', 'answer': 'Solimo', 'path': '8a/8a5e0f6c.jpg'}
# Response for 81fs9aQ+J6L : [{'question': 'What is the material of the cover?', 'answer': 'Canvas'}, {'question': "What is the cover's color?", 'answer': 'Others'}, {'question': 'What is the item weight?', 'answer': '50'}, {'question': 'What is the design on the cover?', 'answer': 'Heart'}, {'question': 'What is the brand name?', 'answer': 'Solimo'}]
# Last record: {'image_id': '81fs9aQ+J6L', 'question': 'What is the brand name?', 'answer': 'Solimo', 'path': '0b/0b8c9e66.jpg'}
# Response for 71Pe79265wL : [{'question': 'What material is the cover made of?', 'answer': 'Silicon'}, {'question': 'What is the item color?', 'answer': 'Multicolor'}, {'question': 'What brand is this?', 'answer': 'Solimo'}, {'question': 'What is the phone model?', 'answer': 'Redmi'}, {'question': 'What is the product type?', 'answer': 'Case'}]
# Last record: {'image_id': '71Pe79265wL', 'question': 'What is the product type?', 'answer': 'Case', 'path': '62/62b5f830.jpg'}
# Response for 71btre9TsiL : [{'question': 'What color is the table?', 'answer': 'Beige'}, {'question': 'What material is the table?', 'answer': 'Wood'}, {'question': "What is the table's style?", 'answer': 'Coffee'}, {'question': "What is the table's width?", 'answer': '22'}, {'question': 'What is the brand?', 'answer': 'Ravenna'}]
# Last record: {'image_id': '71btre9TsiL', 'question': 'What is the brand?', 'answer': 'Ravenna', 'path': '21/21b90013.jpg'}
# Response for 61mRym7BzyL : [{'question': 'What material are the curtains made of?', 'answer': 'Polyester'}, {'question': 'What color are the curtains?', 'answer': 'Beige'}, {'question': 'How many curtains are included?', 'answer': 'Two'}, {'question': 'Are the curtains blackout?', 'answer': 'Yes'}, {'question': "What is the product's brand?", 'answer': 'UMI'}]
# Last record: {'image_id': '61mRym7BzyL', 'question': "What is the product's brand?", 'answer': 'UMI', 'path': '3c/3cba5a56.jpg'}
# Response for 71j4MwESJrL : [{'question': 'What is the item made of?', 'answer': 'Silicon'}, {'question': 'What is the style of the case?', 'answer': 'pattern'}, {'question': 'What brand is this item?', 'answer': 'Solimo'}, {'question': 'What is the phone model?', 'answer': 'Oppo'}, {'question': 'What is the color of the case?', 'answer': 'Multicolor'}]
# Last record: {'image_id': '71j4MwESJrL', 'question': 'What is the color of the case?', 'answer': 'Multicolor', 'path': '10/1043ec2f.jpg'}
# Response for 71iHvEqRBeL : [{'question': 'What color is the shoe?', 'answer': 'Black'}, {'question': 'What type of heel does it have?', 'answer': 'Platform'}, {'question': 'What is the product type?', 'answer': 'Shoes'}, {'question': 'What kind of toe is it?', 'answer': 'Peep'}, {'question': 'What is the brand name?', 'answer': 'Fix'}]
# Last record: {'image_id': '71iHvEqRBeL', 'question': 'What is the brand name?', 'answer': 'Fix', 'path': 'd4/d4495b1d.jpg'}
# Response for 71fR5rFluTL : [{'question': "What is the case's color?", 'answer': 'Multicolor'}, {'question': "What is the case's material?", 'answer': 'Silicon'}, {'question': 'What is the brand?', 'answer': 'Solimo'}, {'question': "What is the pattern's style?", 'answer': 'Pattern'}, {'question': 'What is the phone model?', 'answer': 'A2'}]
# Last record: {'image_id': '71fR5rFluTL', 'question': 'What is the phone model?', 'answer': 'A2', 'path': 'a2/a223fc56.jpg'}
# Response for 81Z1eoJcnrL : [{'question': "What is the item's color?", 'answer': 'Multicoloured'}, {'question': 'What brand is this?', 'answer': 'Solimo'}, {'question': 'Is it hard?', 'answer': 'Yes'}, {'question': 'What is it?', 'answer': 'Case'}, {'question': 'What is it for?', 'answer': 'Phone'}]
# Last record: {'image_id': '81Z1eoJcnrL', 'question': 'What is it for?', 'answer': 'Phone', 'path': 'ba/ba765a47.jpg'}
# Response for 91rkZnAXAJL : [{'question': 'What is the material of the product?', 'answer': 'Poliuretano'}, {'question': 'What color is the product?', 'answer': 'White'}, {'question': "What is the item's country?", 'answer': 'IT'}, {'question': 'What is the marketplace?', 'answer': 'Amazon'}, {'question': 'What is the product type?', 'answer': 'Furniture'}]
# Last record: {'image_id': '91rkZnAXAJL', 'question': 'What is the product type?', 'answer': 'Furniture', 'path': '3f/3f475dd0.jpg'}
# Response for 91PgsAIhYHL : [{'question': "What is the product's material?", 'answer': 'Cotton'}, {'question': 'What pattern is on the duvet?', 'answer': 'Floral'}, {'question': 'What is the product type?', 'answer': 'HOME_BED_AND_BATH'}, {'question': 'How many pillowcases are included?', 'answer': 'Two'}, {'question': 'What brand is this?', 'answer': 'AmazonBasics'}]
# Last record: {'image_id': '91PgsAIhYHL', 'question': 'What brand is this?', 'answer': 'AmazonBasics', 'path': 'f7/f79c77e8.jpg'}
# Response for 71FfugLejLL : [{'question': 'What is the brand?', 'answer': 'Solimo'}, {'question': "What is the case's material?", 'answer': 'Plastic'}, {'question': 'What is the color of the case?', 'answer': 'Multicolor'}, {'question': 'What shape is printed on the case?', 'answer': 'Heart'}, {'question': 'What is the product type?', 'answer': 'Case'}]
# Last record: {'image_id': '71FfugLejLL', 'question': 'What is the product type?', 'answer': 'Case', 'path': '2f/2f934a52.jpg'}
# ...
# Response for 919Tlg45UtL : [{'question': 'What type of case is this?', 'answer': 'Hard'}, {'question': 'What is the color?', 'answer': 'Multi-colored'}, {'question': 'What phone is this for?', 'answer': 'Sony'}, {'question': 'Is it heavy?', 'answer': 'No'}, {'question': 'Is it printed?', 'answer': 'Yes'}]
# Last record: {'image_id': '919Tlg45UtL', 'question': 'Is it printed?', 'answer': 'Yes', 'path': 'ca/cae737c3.jpg'}
# Response for 6162a90IN+L : [{'question': 'What type of item is this?', 'answer': 'Case'}, {'question': 'What is the brand?', 'answer': 'Solimo'}, {'question': 'What is printed at the bottom?', 'answer': 'Queen'}, {'question': 'What is the color?', 'answer': 'Others'}, {'question': 'Is it slim?', 'answer': 'Yes'}]
# Last record: {'image_id': '6162a90IN+L', 'question': 'Is it slim?', 'answer': 'Yes', 'path': '92/92c825e2.jpg'}
# Response for 71QYsKWLT0L : [{'question': 'What is the color of the shoes?', 'answer': 'Burgundy'}, {'question': 'What type of shoe is this?', 'answer': 'Loafer'}, {'question': 'What is the material of the shoe?', 'answer': 'Suede'}, {'question': 'Is the shoe slip-on?', 'answer': 'Yes'}, {'question': 'What is the year of this item?', 'answer': '2017'}]
# Last record: {'image_id': '71QYsKWLT0L', 'question': 'What is the year of this item?', 'answer': '2017', 'path': '21/2137224a.jpg'}
# Response for 71JspQ+tBbL : [{'question': 'What color are the shoes?', 'answer': 'Black'}, {'question': 'What type of shoes are these?', 'answer': 'Formal'}, {'question': 'What is the closure type?', 'answer': 'Lace-Up'}, {'question': 'What brand is this?', 'answer': 'Symbol'}, {'question': 'What is the toe style?', 'answer': 'Round'}]
# Last record: {'image_id': '71JspQ+tBbL', 'question': 'What is the toe style?', 'answer': 'Round', 'path': '72/72cf7dab.jpg'}
# Response for 71VeSUeIwdL : [{'question': "What is the case's color?", 'answer': 'Multicolor'}, {'question': 'What brand is this case?', 'answer': 'Solimo'}, {'question': 'What letter is printed?', 'answer': 'S'}, {'question': 'What type of product is this?', 'answer': 'Case'}, {'question': 'What is the phone model?', 'answer': 'M31'}]
# Last record: {'image_id': '71VeSUeIwdL', 'question': 'What is the phone model?', 'answer': 'M31', 'path': 'c1/c1722125.jpg'}
# Response for 61p5O6qMVTL : [{'question': 'What is the brand of the product?', 'answer': 'AmazonBasics'}, {'question': 'What shape is the lightbulb?', 'answer': 'a19'}, {'question': 'What is the product type?', 'answer': 'LIGHT_BULB'}, {'question': 'What wattage is equivalent to this bulb?', 'answer': '40'}, {'question': 'What color is the light?', 'answer': 'Daylight'}]
# Last record: {'image_id': '61p5O6qMVTL', 'question': 'What color is the light?', 'answer': 'Daylight', 'path': '38/384bcb4a.jpg'}
# Response for 611VevilJGL : [{'question': 'What color is the item?', 'answer': 'Black'}, {'question': 'What is the product material?', 'answer': 'Textil'}, {'question': 'What is the length of the item?', 'answer': '32'}, {'question': 'What is the product?', 'answer': 'Cover'}, {'question': 'What is the fabric?', 'answer': 'Polyester'}]
# Last record: {'image_id': '611VevilJGL', 'question': 'What is the fabric?', 'answer': 'Polyester', 'path': 'c6/c6e16f75.jpg'}
# Response for 71FloLd99kL : [{'question': 'What is the material of the back?', 'answer': 'Wood'}, {'question': 'What is the brand?', 'answer': 'Solimo'}, {'question': 'What is the type of cover?', 'answer': 'Hard'}, {'question': 'What type of printing?', 'answer': '3D'}, {'question': 'What is the phone model?', 'answer': 'Meizu'}]
# Last record: {'image_id': '71FloLd99kL', 'question': 'What is the phone model?', 'answer': 'Meizu', 'path': '04/04c56b7b.jpg'}
# Response for 81oSjj97qgL : [{'question': 'What is the food flavor?', 'answer': 'Blueberry'}, {'question': 'What is the food stage?', 'answer': 'Two'}, {'question': 'What is the brand?', 'answer': 'Mamabear'}, {'question': 'What is the weight?', 'answer': 'Four'}, {'question': 'Is this organic?', 'answer': 'Yes'}]
# Last record: {'image_id': '81oSjj97qgL', 'question': 'Is this organic?', 'answer': 'Yes', 'path': '58/58b5a726.jpg'}
# Response for 61Yug8fG7UL : [{'question': 'What color is this item?', 'answer': 'Yellow'}, {'question': 'What is the product type?', 'answer': 'Chair'}, {'question': "What is the item's weight?", 'answer': 'Pounds'}, {'question': 'Does it require assembly?', 'answer': 'No'}, {'question': 'Where was this made?', 'answer': 'China'}]
# Last record: {'image_id': '61Yug8fG7UL', 'question': 'Where was this made?', 'answer': 'China', 'path': '73/73ca946b.jpg'}
# Response for 61CUZiYjgQL : [{'question': 'What color is the tray?', 'answer': 'White'}, {'question': 'What is the tray made of?', 'answer': 'Plastic'}, {'question': 'What is the height in inches?', 'answer': '3.35'}, {'question': 'Can this tray stack?', 'answer': 'Yes'}, {'question': 'Is it heavy?', 'answer': 'No'}]
# Last record: {'image_id': '61CUZiYjgQL', 'question': 'Is it heavy?', 'answer': 'No', 'path': '10/1031092e.jpg'}
# Response for 81khCTPM8qL : [{'question': 'What color is the shoe?', 'answer': 'Gris'}, {'question': 'What type of shoes are these?', 'answer': 'Casuales'}, {'question': 'What is the brand?', 'answer': 'Skechers'}, {'question': 'Are these slip-ons?', 'answer': 'Yes'}, {'question': 'What is the product type?', 'answer': 'Shoes'}]
# Last record: {'image_id': '81khCTPM8qL', 'question': 'What is the product type?', 'answer': 'Shoes', 'path': '7a/7aea55ef.jpg'}
# Response for 71h0EZDkgAL : [{'question': "What is the product's color?", 'answer': 'Others'}, {'question': 'What is the item material?', 'answer': 'Glass'}, {'question': 'What is the model name?', 'answer': 'Vivo'}, {'question': "What is the item's brand?", 'answer': 'Solimo'}, {'question': 'Is the case multicolored?', 'answer': 'Yes'}]
# Last record: {'image_id': '71h0EZDkgAL', 'question': 'Is the case multicolored?', 'answer': 'Yes', 'path': '0d/0d410378.jpg'}
# Response for 61wLwK5nyoL : [{'question': 'What is the color of the product?', 'answer': 'Multicolor'}, {'question': 'What phone is this case for?', 'answer': 'OPPO'}, {'question': "What is the item's material?", 'answer': 'TPU'}, {'question': 'What type of case is this?', 'answer': 'Back'}, {'question': 'What brand is the case?', 'answer': 'Solimo'}]
# Last record: {'image_id': '61wLwK5nyoL', 'question': 'What brand is the case?', 'answer': 'Solimo', 'path': '10/109ec740.jpg'}
# Response for 614eCcL3FlL : [{'question': 'What kind of shoes are these?', 'answer': 'Sandals'}, {'question': 'What color are the straps?', 'answer': 'Black'}, {'question': 'What is the brand name?', 'answer': 'find'}, {'question': 'What is the product category?', 'answer': 'Shoes'}, {'question': 'What animal print is present?', 'answer': 'Leopard'}]
# Last record: {'image_id': '614eCcL3FlL', 'question': 'What animal print is present?', 'answer': 'Leopard', 'path': '2f/2fe14e0e.jpg'}
# Response for 71ew7MhC1vL : [{'question': "What is the bracelet's color?", 'answer': 'Black'}, {'question': 'What letter is on the charm?', 'answer': 'L'}, {'question': 'What is the item plating?', 'answer': 'Silver'}, {'question': 'What is the marketplace?', 'answer': 'Amazon'}, {'question': "What is the item's style?", 'answer': 'Bracelet'}]
# Last record: {'image_id': '71ew7MhC1vL', 'question': "What is the item's style?", 'answer': 'Bracelet', 'path': '48/48004108.jpg'}
# Response for 51xBN3J8v+L : [{'question': 'What kind of ice cream is this?', 'answer': 'Mint'}, {'question': 'What is the marketplace?', 'answer': 'WholeFoods'}, {'question': 'How much does the ice cream weigh?', 'answer': '2.28'}, {'question': 'What is the product type?', 'answer': 'Grocery'}, {'question': 'What is the brand name?', 'answer': '365'}]
# Last record: {'image_id': '51xBN3J8v+L', 'question': 'What is the brand name?', 'answer': '365', 'path': '8d/8de39eca.jpg'}
# Response for 61IdZ8R33uL : [{'question': 'What shape are the stones?', 'answer': 'Round'}, {'question': 'What type of earring is this?', 'answer': 'Stud'}, {'question': 'What metal are the earrings?', 'answer': 'Silver'}, {'question': 'What are the earrings made of?', 'answer': 'Cubic'}, {'question': 'How many earrings?', 'answer': 'Two'}]
# Last record: {'image_id': '61IdZ8R33uL', 'question': 'How many earrings?', 'answer': 'Two', 'path': 'cb/cbd1f814.jpg'}
# Response for 81bSnHfQTHL : [{'question': 'What color is the tie?', 'answer': 'Silver'}, {'question': 'What is the fabric of this item?', 'answer': 'Silk'}, {'question': 'What is the brand of this accessory?', 'answer': 'Buttoned'}, {'question': 'What type of product is this?', 'answer': 'Accessory'}, {'question': 'What is the style of the tie?', 'answer': 'Skinny'}]
# Last record: {'image_id': '81bSnHfQTHL', 'question': 'What is the style of the tie?', 'answer': 'Skinny', 'path': '9e/9ec56260.jpg'}
# Response for 819Q4iYBdDL : [{'question': 'What type of case is this?', 'answer': 'Back'}, {'question': 'What phone is this case for?', 'answer': 'Nokia'}, {'question': "What is the cover's brand?", 'answer': 'Solimo'}, {'question': "What is the case's color?", 'answer': 'Multi-colored'}, {'question': 'Is the back cover hard?', 'answer': 'Yes'}]
# Last record: {'image_id': '819Q4iYBdDL', 'question': 'Is the back cover hard?', 'answer': 'Yes', 'path': 'a3/a3608d3a.jpg'}
# Response for 61urmkY6EOL : [{'question': 'What is the brand name?', 'answer': 'Solimo'}, {'question': 'What kind of case is this?', 'answer': 'Hard'}, {'question': 'What is this an accessory for?', 'answer': 'Mobile'}, {'question': 'What color is the item?', 'answer': 'Others'}, {'question': 'Does it have a warranty?', 'answer': 'No'}]
# Last record: {'image_id': '61urmkY6EOL', 'question': 'Does it have a warranty?', 'answer': 'No', 'path': 'cd/cdba0778.jpg'}
# Response for 81PONz1p2bL : [{'question': 'What is the item color?', 'answer': 'Others'}, {'question': 'What is the brand?', 'answer': 'Solimo'}, {'question': 'Is this a hard case?', 'answer': 'Yes'}, {'question': 'What is the item?', 'answer': 'Case'}, {'question': 'What phone is this case for?', 'answer': 'Samsung'}]
# Last record: {'image_id': '81PONz1p2bL', 'question': 'What phone is this case for?', 'answer': 'Samsung', 'path': 'cc/cca26e6d.jpg'}
# Response for 71epOU8UBbL : [{'question': 'What is the color of the phone case?', 'answer': 'Multi-colored'}, {'question': 'What type of case is this?', 'answer': 'Hard'}, {'question': 'What is the brand of this case?', 'answer': 'Solimo'}, {'question': "What is the item's weight in pounds?", 'answer': '0.110231131'}, {'question': 'What is the case designed with?', 'answer': 'Leafs'}]
# Last record: {'image_id': '71epOU8UBbL', 'question': 'What is the case designed with?', 'answer': 'Leafs', 'path': 'a9/a90ae7b0.jpg'}
# Response for 81hlLZ31XlL : [{'question': 'What brand is the case?', 'answer': 'Solimo'}, {'question': 'What is the item weight in grams?', 'answer': '50'}, {'question': 'What type of case is this?', 'answer': 'Back'}, {'question': "What is the case's color?", 'answer': 'Others'}, {'question': 'For which model is this case?', 'answer': 'Samsung'}]
# Last record: {'image_id': '81hlLZ31XlL', 'question': 'For which model is this case?', 'answer': 'Samsung', 'path': '73/734341f6.jpg'}
# Response for 61ZNp4-1rEL : [{'question': 'What shape are the earrings?', 'answer': 'Cross'}, {'question': 'What material is the jewelry?', 'answer': 'Gold'}, {'question': "What is the item's type?", 'answer': 'Earring'}, {'question': 'What is the color of gems?', 'answer': 'Pink'}, {'question': 'What stones are used?', 'answer': 'Zirconia'}]
# Last record: {'image_id': '61ZNp4-1rEL', 'question': 'What stones are used?', 'answer': 'Zirconia', 'path': '55/55ed3620.jpg'}
# Response for 61644k-IaYL : [{'question': "What is the case's brand?", 'answer': 'Solimo'}, {'question': "What is the case's color?", 'answer': 'Multicoloured'}, {'question': 'What is the model?', 'answer': 'Xiaomi'}, {'question': 'What does the case protect from?', 'answer': 'Scratches'}, {'question': 'Is the phone case printed?', 'answer': 'Yes'}]
# Last record: {'image_id': '61644k-IaYL', 'question': 'Is the phone case printed?', 'answer': 'Yes', 'path': 'd1/d10ede28.jpg'}
# No main image for: B074H7Y817
# Response for 71UggUV-dDL : [{'question': 'What is the color?', 'answer': 'Multi-colored'}, {'question': 'What is the brand?', 'answer': 'Solimo'}, {'question': 'What type of product?', 'answer': 'Case'}, {'question': 'What is the weight?', 'answer': '50'}, {'question': 'Is it hard?', 'answer': 'Yes'}]
# Last record: {'image_id': '71UggUV-dDL', 'question': 'Is it hard?', 'answer': 'Yes', 'path': 'e6/e61f18f9.jpg'}
# Response for 812EjD3CovL : [{'question': 'What kind of fruit is this?', 'answer': 'Prunes'}, {'question': 'Is this fat free?', 'answer': 'Yes'}, {'question': 'What is the brand?', 'answer': '365'}, {'question': 'What is the net weight?', 'answer': 'Eight'}, {'question': 'Are these dried?', 'answer': 'Yes'}]
# Last record: {'image_id': '812EjD3CovL', 'question': 'Are these dried?', 'answer': 'Yes', 'path': '3b/3b49f1c5.jpg'}
# Response for 81nFgU+pW9L : [{'question': 'What color are the curtains?', 'answer': 'Green'}, {'question': 'How many curtains are there?', 'answer': 'Two'}, {'question': "What is the product's brand?", 'answer': 'Solimo'}, {'question': 'What are the curtains made of?', 'answer': 'Polycotton'}, {'question': "What is the curtain's pattern?", 'answer': 'Modern'}]
# Last record: {'image_id': '81nFgU+pW9L', 'question': "What is the curtain's pattern?", 'answer': 'Modern', 'path': 'fd/fdd090ee.jpg'}
# Response for 81jooMhS9JL : [{'question': 'What color is the wardrobe?', 'answer': 'White'}, {'question': "What is the wardrobe's brand?", 'answer': 'Movian'}, {'question': "What is the item's material?", 'answer': 'Trä'}, {'question': 'How many doors does it have?', 'answer': 'Two'}, {'question': 'Is this product furniture?', 'answer': 'Yes'}]
# Last record: {'image_id': '81jooMhS9JL', 'question': 'Is this product furniture?', 'answer': 'Yes', 'path': 'e5/e55df3f7.jpg'}
# Response for 61kTzp20kNL : [{'question': 'What is the color of the case?', 'answer': 'Multicolor'}, {'question': 'What is the material of the case?', 'answer': 'Silicone'}, {'question': 'What is the style of the case?', 'answer': 'pattern'}, {'question': 'What is the brand of the case?', 'answer': 'Solimo'}, {'question': "What is the item's product type?", 'answer': 'CELLULAR_PHONE_CASE'}]
# Last record: {'image_id': '61kTzp20kNL', 'question': "What is the item's product type?", 'answer': 'CELLULAR_PHONE_CASE', 'path': '30/3025262a.jpg'}
# Response for 71j8l5eJtNL : [{'question': 'What color are the shoes?', 'answer': 'Azul'}, {'question': 'What is the product type?', 'answer': 'Shoes'}, {'question': 'What is the brand?', 'answer': 'Jenny'}, {'question': 'What is the model year?', 'answer': '2019'}, {'question': 'Are they sandals?', 'answer': 'Yes'}]
# Last record: {'image_id': '71j8l5eJtNL', 'question': 'Are they sandals?', 'answer': 'Yes', 'path': '99/99900189.jpg'}
# Response for 81BEz-LdB6L : [{'question': "What is the item's color?", 'answer': 'Others'}, {'question': 'What type of case is this?', 'answer': 'Hard'}, {'question': "What is the item's brand?", 'answer': 'Solimo'}, {'question': "What is the item's model?", 'answer': 'Asus'}, {'question': 'What is the weight in grams?', 'answer': '50'}]
# Last record: {'image_id': '81BEz-LdB6L', 'question': 'What is the weight in grams?', 'answer': '50', 'path': 'bf/bf24b051.jpg'}
# Response for 81mqFKUK5gL : [{'question': 'What kind of oil is this?', 'answer': 'Olive'}, {'question': 'What is the brand name?', 'answer': 'Solimo'}, {'question': 'What is it ideal for?', 'answer': 'Frying'}, {'question': 'What kind of cooking is this oil for?', 'answer': 'Indian'}, {'question': 'Which country is this from?', 'answer': 'Italy'}]
# Last record: {'image_id': '81mqFKUK5gL', 'question': 'Which country is this from?', 'answer': 'Italy', 'path': 'b4/b4aa76f4.jpg'}

# %%
vqa_df = pd.DataFrame(records)
vqa_df.to_csv("vqa_dataset.csv", index=False)
print("Generated", len(vqa_df), "Q&A pairs across all images")
